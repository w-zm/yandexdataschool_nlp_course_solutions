# %% [markdown]
# ## Seminar 1: Fun with Word Embeddings (3 points)
#
# Today we gonna play with word embeddings: train our own little embedding, load one from   gensim model zoo and use it to visualize text corpora.
#
# This whole thing is gonna happen on top of embedding dataset.
#
# __Requirements:__  `pip install --upgrade nltk gensim bokeh` , but only if you're running locally.

# %%
# download the data:
# !wget https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt
# alternative download link: https://yadi.sk/i/BPQrUu1NaTduEw
# Out:
# 'wget' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
import numpy as np

data = list(open("./quora.txt", encoding='utf8'))
data[50]
# Out:
# "What TV shows or books help you read people's body language?\n"

# %% [markdown]
# __Tokenization:__ a typical first step for an nlp task is to split raw data into words.
# The text we're working with is in raw format: with all the punctuation and smiles attached to some words, so a simple str.split won't do.
#
# Let's use __`nltk`__ - a library that handles many nlp tasks like tokenization, stemming or part-of-speech tagging.

# %%
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()

print(tokenizer.tokenize(data[50]))
# Out:
# ['What', 'TV', 'shows', 'or', 'books', 'help', 'you', 'read', 'people', "'", 's', 'body', 'language', '?']

# %%
# TASK: lowercase everything and extract tokens with tokenizer. 
# data_tok should be a list of lists of tokens for each line in data.

data_tok = []

for i in data:
    data_tok.append([j.lower() for j in tokenizer.tokenize(i)])

# %%
data_tok
# Out:
# [['can',
#   'i',
#   'get',
#   'back',
#   'with',
#   'my',
#   'ex',
#   'even',
#   'though',
#   'she',
#   'is',
#   'pregnant',
#   'with',
#   'another',
#   'guy',
#   "'",
#   's',
#   'baby',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'ways',
#   'to',
#   'overcome',
#   'a',
#   'fast',
#   'food',
#   'addiction',
#   '?'],
#  ['who',
#   'were',
#   'the',
#   'great',
#   'chinese',
#   'soldiers',
#   'and',
#   'leaders',
#   'who',
#   'fought',
#   'in',
#   'ww2',
#   '?'],
#  ['what', 'are', 'zip', 'codes', 'in', 'the', 'bay', 'area', '?'],
#  ['why',
#   'was',
#   'george',
#   'rr',
#   'martin',
#   'critical',
#   'of',
#   'jk',
#   'rowling',
#   'after',
#   'losing',
#   'the',
#   'hugo',
#   'award',
#   '?'],
#  ['what', 'can', 'i', 'do', 'to', 'improve', 'my', 'immune', 'system', '?'],
#  ['how',
#   'is',
#   'your',
#   'relationship',
#   'with',
#   'your',
#   'mother',
#   'in',
#   'law',
#   '?'],
#  ['how',
#   'does',
#   'one',
#   'get',
#   'free',
#   'psn',
#   'codes',
#   '/',
#   'vita',
#   'codes',
#   '?'],
#  ['what', 'is', 'your', 'review', 'of', 'osquery', '?'],
#  ['how', 'can', 'i', 'look', 'smart', 'and', 'act', 'smart', '?'],
#  ['which',
#   'brand',
#   'should',
#   'go',
#   'with',
#   'the',
#   'gtx',
#   '960',
#   'graphic',
#   'card',
#   ',',
#   'msi',
#   ',',
#   'zotac',
#   'or',
#   'asus',
#   '?'],
#  ['what', 'is', 'the', 'zip', 'code', 'of', 'india', '?'],
#  ['as',
#   'an',
#   'indian',
#   'doctor',
#   'practicing',
#   'in',
#   'my',
#   'own',
#   'private',
#   'clinic',
#   '.',
#   'how',
#   'can',
#   'i',
#   'earn',
#   'more',
#   '?',
#   'what',
#   'other',
#   'sources',
#   'of',
#   'income',
#   'can',
#   'i',
#   'use',
#   '?'],
#  ['is',
#   'windows',
#   'the',
#   'only',
#   'os',
#   'that',
#   'is',
#   'not',
#   'based',
#   'on',
#   'unix',
#   'or',
#   'linux',
#   '?'],
#  ['how', 'can', 'i', 'avoid', 'using', 'facebook', '?'],
#  ['how',
#   'do',
#   'you',
#   'get',
#   'a',
#   'norton',
#   'security',
#   'renewal',
#   'code',
#   '?'],
#  ['does',
#   'emc',
#   'plan',
#   'a',
#   'lightweight',
#   'web',
#   'client',
#   'for',
#   'documentum',
#   '?'],
#  ['where',
#   'is',
#   'the',
#   'strangest',
#   'place',
#   'you',
#   "'",
#   've',
#   'ever',
#   'masturbated',
#   '?'],
#  ['tamil',
#   'nadu',
#   ',',
#   'india',
#   ':',
#   'what',
#   'can',
#   'we',
#   'learn',
#   'from',
#   'ex',
#   'cm',
#   'j',
#   '.',
#   'jayalalitha',
#   '?'],
#  ['which',
#   'car',
#   'should',
#   'i',
#   'buy',
#   'out',
#   'of',
#   'tiago',
#   ',',
#   'kwid',
#   ',',
#   'figo',
#   ',',
#   'datsun',
#   'or',
#   'any',
#   'other',
#   '?'],
#  ['who', 'discovered', 'plate', 'tectonics', 'and', 'how', '?'],
#  ['is',
#   'the',
#   'earth',
#   'the',
#   'only',
#   'planet',
#   'that',
#   'has',
#   'life',
#   'on',
#   'it',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'get',
#   'a',
#   'ride',
#   'on',
#   'a',
#   'civilian',
#   'c',
#   '-',
#   '130',
#   '?'],
#  ['what', 'does', 'entertainment', 'mean', 'for', 'you', '?'],
#  ['how',
#   'is',
#   'the',
#   'experience',
#   'to',
#   'be',
#   'an',
#   'extra',
#   'on',
#   'the',
#   'show',
#   '-',
#   'how',
#   'i',
#   'met',
#   'your',
#   'mother',
#   '?'],
#  ['will',
#   'windows',
#   'run',
#   'well',
#   'enough',
#   'to',
#   'use',
#   'excel',
#   'and',
#   'outlook',
#   'in',
#   'a',
#   'vm',
#   'on',
#   'the',
#   'new',
#   '2015',
#   'macbook',
#   '?'],
#  ['is',
#   'it',
#   'true',
#   'that',
#   'ancient',
#   'china',
#   'had',
#   'no',
#   'glass',
#   '?',
#   'or',
#   'was',
#   'it',
#   'no',
#   'clear',
#   'glass',
#   '?',
#   'or',
#   'not',
#   '?'],
#  ['what', 'is', 'your', 'review', 'of', 'ipad', 'mini', '2', '?'],
#  ['what', 'is', 'the', 'purpose', 'of', 'steam', 'turbine', '?'],
#  ['when',
#   'do',
#   'you',
#   'really',
#   'need',
#   'to',
#   'create',
#   'an',
#   'abstract',
#   'class',
#   '?'],
#  ['how', 'are', 'dalmatian', 'dogs', 'like', 'as', 'pets', '?'],
#  ['are',
#   'drivers',
#   'within',
#   'rich',
#   'countries',
#   'less',
#   'likely',
#   'to',
#   'slow',
#   'down',
#   'when',
#   'they',
#   'see',
#   'a',
#   'driver',
#   "'",
#   's',
#   'turn',
#   'signal',
#   '?'],
#  ['are', 'asian', 'girls', 'attracted', 'to', 'black', 'guys', '?'],
#  ['from',
#   'where',
#   'can',
#   'i',
#   'buy',
#   'castor',
#   'oil',
#   'for',
#   'hair',
#   'in',
#   'mumbai',
#   '?'],
#  ['does',
#   'cvs',
#   'still',
#   'develop',
#   'film',
#   '?',
#   'why',
#   'or',
#   'why',
#   'not',
#   '?'],
#  ['can', 'china', 'always', 'print', 'money', '?'],
#  ['what', 'is', 'fake', 'software', '?'],
#  ['how', 'do', 'students', 'at', 'iit', 'get', 'foreign', 'internships', '?'],
#  ['how', 'do', 'i', 'find', 'my', 'life', "'", 's', 'goal', '?'],
#  ['what', 'are', 'the', 'upcoming', 'mobiles', '?'],
#  ['what',
#   'is',
#   'the',
#   'chemical',
#   'formula',
#   'for',
#   'hydrochloric',
#   'acid',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'biggest',
#   'disneyland',
#   'in',
#   'the',
#   'world',
#   '?',
#   'what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'get',
#   'entrance',
#   'tickets',
#   'for',
#   'it',
#   '?'],
#  ['how', 'does', 'the', 'finance', 'credit', 'score', 'work', '?'],
#  ['how', 'do', 'i', 'meet', 'foreign', 'guys', 'in', 'hong', 'kong', '?'],
#  ['is', 'the', 'atm', 'business', 'still', 'viable', '?'],
#  ['how',
#   'can',
#   'i',
#   'learn',
#   'to',
#   'speak',
#   'english',
#   'well',
#   'in',
#   'non',
#   '-',
#   'english',
#   'environment',
#   '?'],
#  ['can',
#   'a',
#   'high',
#   'school',
#   'student',
#   'get',
#   'an',
#   'internship',
#   'at',
#   'goldman',
#   'sachs',
#   '?'],
#  ['who', 'are', 'the', 'top', 'business', 'coaches', 'in', 'australia', '?'],
#  ['why', 'do', 'girls', 'wait', 'for', 'boys', 'to', 'propose', '?'],
#  ['should',
#   'cricket',
#   'be',
#   'our',
#   'national',
#   'sport',
#   'and',
#   'not',
#   'hockey',
#   '?'],
#  ['what',
#   'tv',
#   'shows',
#   'or',
#   'books',
#   'help',
#   'you',
#   'read',
#   'people',
#   "'",
#   's',
#   'body',
#   'language',
#   '?'],
#  ['i',
#   'see',
#   'this',
#   'cute',
#   'girl',
#   'around',
#   'my',
#   'college',
#   '.',
#   'i',
#   "'",
#   'm',
#   'too',
#   'shy',
#   'to',
#   'approach',
#   'her',
#   '.',
#   'is',
#   'it',
#   'acceptable',
#   'to',
#   'leave',
#   'her',
#   'a',
#   'note',
#   'with',
#   'my',
#   'feelings',
#   'and',
#   'number',
#   '?'],
#  ['what',
#   'schools',
#   'can',
#   'i',
#   'apply',
#   'for',
#   'with',
#   'a',
#   'gre',
#   'score',
#   'of',
#   'q',
#   '-',
#   '165',
#   'v',
#   '-',
#   '153',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'solution',
#   'for',
#   'this',
#   'quickbooks',
#   'error',
#   '12031',
#   '?'],
#  ['do',
#   'you',
#   'think',
#   'the',
#   'aap',
#   'will',
#   'fulfill',
#   'the',
#   'promises',
#   'they',
#   'mentioned',
#   'in',
#   'their',
#   'manifesto',
#   '?',
#   'why',
#   'and',
#   'how',
#   '?'],
#  ['what',
#   'are',
#   'all',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'having',
#   'dual',
#   'citizenship',
#   '?'],
#  ['can',
#   'someone',
#   'translate',
#   'this',
#   'one',
#   'from',
#   'italian',
#   'or',
#   'latin',
#   '?'],
#  ['what', 'is', '“', 'directive', '”?'],
#  ['what', 'is', 'the', 'density', 'and', 'volume', 'of', 'black', 'hole', '?'],
#  ['what', 'does', '"', 'las', 'vegas', '"', 'mean', '?'],
#  ['is',
#   'it',
#   'possible',
#   'to',
#   'lick',
#   'a',
#   'toad',
#   'and',
#   'get',
#   'high',
#   '?'],
#  ['who', 'nominates', 'the', 'president', 'of', 'india', '?'],
#  ['how',
#   'does',
#   'linkedin',
#   'work',
#   '?',
#   'i',
#   "'",
#   'm',
#   'getting',
#   'connections',
#   'so',
#   'now',
#   'what',
#   '?',
#   'how',
#   'do',
#   'i',
#   'find',
#   'a',
#   'job',
#   '?'],
#  ['how', 'can', 'i', 'record', 'a', 'facetime', 'call', 'on', 'a', 'mac', '?'],
#  ['what', 'are', 'the', 'application', 'of', 'binary', 'search', 'trees', '?'],
#  ['why',
#   'do',
#   'symptoms',
#   'persist',
#   'even',
#   'when',
#   'you',
#   'know',
#   'they',
#   'are',
#   'psychosomatic',
#   '?'],
#  ['what', 'are', 'the', 'best', 'digital', 'marketing', 'agencies', '?'],
#  ['why',
#   'is',
#   'my',
#   '128gb',
#   'micro',
#   'sd',
#   'card',
#   "'",
#   's',
#   'capacity',
#   'reduced',
#   'to',
#   '119gb',
#   '?',
#   'in',
#   'linux',
#   'it',
#   'showed',
#   '128gb',
#   '.',
#   'but',
#   'now',
#   'it',
#   'only',
#   'shows',
#   'said',
#   'capacity',
#   'even',
#   'in',
#   'ubuntu',
#   '.'],
#  ['did', 'you', 'visit', 'vietnam', '?'],
#  ['are', 'there', 'any', 'nobel', 'prize', 'winners', 'on', 'quora', '?'],
#  ['what', 'are', 'the', 'alternatives', 'to', 'walkme', '?'],
#  ['is', 'love', 'the', 'most', 'precious', 'thing', 'in', 'life', '?'],
#  ['how',
#   'can',
#   'i',
#   'download',
#   'cool',
#   'stuff',
#   'on',
#   'my',
#   'iphone',
#   'like',
#   'they',
#   'have',
#   'on',
#   'cydia',
#   'cause',
#   'i',
#   "'",
#   'm',
#   'not',
#   'jailbroken',
#   '?'],
#  ['how', 'do', 'i', 'start', 'investing', 'in', 'stocks', 'with', '100', '€?'],
#  ['what',
#   'is',
#   'quantitative',
#   'analysis',
#   'in',
#   'finance',
#   '?',
#   'how',
#   'is',
#   'it',
#   'applied',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'process',
#   'to',
#   'be',
#   'a',
#   'guest',
#   'speaker',
#   'on',
#   'npr',
#   '?'],
#  ['we',
#   'can',
#   "'",
#   't',
#   'see',
#   'the',
#   'universe',
#   'beyond',
#   'our',
#   'time',
#   'and',
#   'mind',
#   '.',
#   'why',
#   '?'],
#  ['what', 'does', 'a', 'programmer', 'do', 'at', 'their', 'job', '?'],
#  ['why',
#   'does',
#   'china',
#   'not',
#   'want',
#   'to',
#   'be',
#   'seen',
#   'as',
#   'a',
#   'superpower',
#   '?',
#   'while',
#   'india',
#   'is',
#   'very',
#   'keen',
#   'on',
#   'being',
#   'seen',
#   'as',
#   'one',
#   '?'],
#  ['for',
#   'the',
#   'g',
#   '+',
#   '5',
#   'building',
#   ',',
#   'what',
#   'is',
#   'the',
#   'minimum',
#   'steel',
#   'section',
#   'used',
#   'as',
#   'bracings',
#   'in',
#   'staad',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'most',
#   'epic',
#   'photos',
#   'ever',
#   'taken',
#   '?'],
#  ['why',
#   'do',
#   'our',
#   'feet',
#   'and',
#   'other',
#   'body',
#   'parts',
#   '"',
#   'fall',
#   'asleep',
#   '"?'],
#  ['who', 'are', 'the', 'true', 'muslims', ',', 'shia', 'or', 'sunni', '?'],
#  ['how',
#   'much',
#   'can',
#   'be',
#   'served',
#   'with',
#   'a',
#   'liter',
#   'bottle',
#   'of',
#   'vodka',
#   '?'],
#  ['why',
#   'do',
#   'people',
#   'pay',
#   'for',
#   'netflix',
#   'when',
#   'they',
#   'can',
#   'stream',
#   'online',
#   'for',
#   'free',
#   'and',
#   'in',
#   'better',
#   'quality',
#   '?'],
#  ['is', 'euthanasia', 'ever', 'morally', 'permissible', '?'],
#  ['is',
#   'it',
#   'worth',
#   'it',
#   'to',
#   'loose',
#   'your',
#   'virginity',
#   'as',
#   'a',
#   'freshman',
#   'in',
#   'high',
#   'school',
#   '?'],
#  ['what',
#   'do',
#   'you',
#   'think',
#   'about',
#   'rbi',
#   'directive',
#   'of',
#   'allowing',
#   'only',
#   'once',
#   'to',
#   'deposit',
#   'old',
#   'notes',
#   'in',
#   'bank',
#   'account',
#   '?'],
#  ['what',
#   'hill',
#   'station',
#   '/',
#   'picnic',
#   'spot',
#   'is',
#   'of',
#   'equal',
#   'distance',
#   'from',
#   'bangalore',
#   'and',
#   'pune',
#   '?'],
#  ['how', 'can', 'i', 'make', 'myself', 'read', 'an', 'entire', 'book', '?'],
#  ['how', 'do', 'you', 'become', 'chancellor', 'of', 'a', 'university', '?'],
#  ['if', 'trump', 'wins', 'will', 'there', 'be', 'a', 'nuclear', 'war', '?'],
#  ['how',
#   'do',
#   'i',
#   'prevent',
#   'users',
#   'on',
#   'the',
#   'same',
#   'netflix',
#   'account',
#   'from',
#   'seeing',
#   'my',
#   'profile',
#   '?'],
#  ['what', 'was', 'osama', 'bin', 'laden', 'like', 'as', 'a', 'person', '?'],
#  ['which',
#   'was',
#   'the',
#   'best',
#   'porn',
#   'video',
#   'you',
#   'have',
#   'ever',
#   'seen',
#   '?',
#   'why',
#   'was',
#   'that',
#   'the',
#   'best',
#   'one',
#   '?'],
#  ['how', 'can', 'i', 'get', 'sbi', 'transaction', 'id', '?'],
#  ['what',
#   'is',
#   'a',
#   'good',
#   'way',
#   'to',
#   'start',
#   'studying',
#   'for',
#   'a',
#   'career',
#   'in',
#   'cybersecurity',
#   '?'],
#  ['what', 'are', 'the', 'components', 'of', 'fitness', '?'],
#  ['what',
#   'is',
#   'the',
#   'good',
#   'approach',
#   'to',
#   'implement',
#   'rest',
#   'api',
#   'either',
#   'to',
#   'go',
#   'with',
#   'http',
#   'status',
#   'codes',
#   'or',
#   'creating',
#   'custom',
#   'error',
#   'field',
#   'by',
#   'always',
#   'returning',
#   '200',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'iupac',
#   'name',
#   'of',
#   'tert',
#   '-',
#   'butyl',
#   'chloride',
#   '?'],
#  ['how', 'similar', 'are', 'soylent', 'and', 'ensure', 'nutritionally', '?'],
#  ['what', 'is', 'the', 'future', 'of', 'sociology', 'education', '?'],
#  ['how', 'can', 'i', 'choose', 'to', 'make', 'the', 'right', 'decision', '?'],
#  ['what', 'does', 'void', '*', 'p', '=', '&', 'p', 'mean', 'in', 'c', '++?'],
#  ['can',
#   'you',
#   'take',
#   'mucinex',
#   'if',
#   'you',
#   'have',
#   'high',
#   'blood',
#   'pressure',
#   '?'],
#  ['which',
#   'universities',
#   'have',
#   'good',
#   'ph',
#   '.',
#   'd',
#   'programs',
#   'in',
#   'image',
#   'processing',
#   'and',
#   'computer',
#   'vision',
#   '?'],
#  ['what', 'is', 'your', 'favorite', 'moment', 'with', 'quora', '?'],
#  ['how', 'can', 'i', 'make', 'studying', 'more', 'interesting', '?'],
#  ['how',
#   'are',
#   'the',
#   'balloons',
#   'designed',
#   'and',
#   'built',
#   'for',
#   'the',
#   'macy',
#   "'",
#   's',
#   'thanksgiving',
#   'day',
#   'parade',
#   '?'],
#  ['what', 'is', 'the', 'significance', 'of', 'bicsi', 'cec', '?'],
#  ['how', 'do', 'you', 'set', 'a', 'honeywell', 'thermostat', '?'],
#  ['which',
#   'needs',
#   'more',
#   'power',
#   'in',
#   'a',
#   'laptop',
#   ',',
#   'gaming',
#   'or',
#   'video',
#   'editing',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'meaning',
#   'of',
#   'a',
#   'hindi',
#   'word',
#   'ब',
#   'े',
#   'दब',
#   'ी?'],
#  ['what',
#   'are',
#   'some',
#   'good',
#   'books',
#   'to',
#   'learn',
#   'data',
#   'structures',
#   'and',
#   'algorithms',
#   'for',
#   'a',
#   'beginner',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'answers',
#   'written',
#   'on',
#   'women',
#   'empowerment',
#   '?'],
#  ['what',
#   'makes',
#   'isis',
#   'attractive',
#   'for',
#   'the',
#   'youth',
#   'living',
#   'in',
#   'the',
#   'western',
#   'countries',
#   '?'],
#  ['what', 'is', 'adding', '1', '/', '2', 'to', '1', '/', '4', 'equals', '?'],
#  ['how',
#   'do',
#   'i',
#   'differentiate',
#   'between',
#   'human',
#   'and',
#   'animal',
#   'blood',
#   '?'],
#  ['what', 'is', 'the', 'difference', 'between', 'watts', 'and', 'lumens', '?'],
#  ['how', 'does', 'getting', 'a', 'divorce', 'change', 'your', 'life', '?'],
#  ['what', 'happens', 'to', 'my', 'stock', 'options', 'when', 'i', 'quit', '?'],
#  ['do', 'fetuses', 'suffer', 'during', 'an', 'abortion', '?'],
#  ['chefs',
#   ',',
#   'do',
#   'you',
#   'write',
#   'your',
#   'own',
#   'menus',
#   'for',
#   'cooking',
#   'at',
#   'home',
#   '?',
#   'i',
#   'made',
#   'a',
#   'static',
#   'menu',
#   'with',
#   'three',
#   'cuisines',
#   '.',
#   'do',
#   'you',
#   'have',
#   'tips',
#   'for',
#   'writing',
#   'menus',
#   '?'],
#  ['how', 'do', 'i', 'make', 'best', 'use', 'of', 'ieee', '?'],
#  ['what', 'are', 'the', 'uga', 'sat', 'score', 'requirements', '?'],
#  ['i',
#   'get',
#   'aroused',
#   'when',
#   'i',
#   'see',
#   'movie',
#   'scene',
#   'where',
#   'slave',
#   'get',
#   'whipped',
#   'and',
#   'get',
#   'excited',
#   'when',
#   'see',
#   'red',
#   'strips',
#   'on',
#   'their',
#   'back',
#   '.',
#   'is',
#   'it',
#   'normal',
#   '?'],
#  ['what',
#   'distinguishes',
#   'litigation',
#   'from',
#   'other',
#   'forms',
#   'of',
#   'legal',
#   'intervention',
#   '?'],
#  ['are', 'all', 'good', 'deeds', 'inherently', 'selfish', '?'],
#  ['which',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'horror',
#   'hollywood',
#   'movies',
#   'to',
#   'watch',
#   '?'],
#  ['in',
#   'the',
#   'case',
#   'of',
#   'a',
#   'power',
#   'plant',
#   ',',
#   'what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'a',
#   'synchronous',
#   'generator',
#   'and',
#   'an',
#   'asynchronous',
#   'generator',
#   '?',
#   'which',
#   'is',
#   'preferred',
#   'and',
#   'why',
#   '?'],
#  ['if',
#   'the',
#   'education',
#   'system',
#   'in',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'is',
#   'really',
#   'bad',
#   ',',
#   'why',
#   'are',
#   'people',
#   'all',
#   'over',
#   'the',
#   'world',
#   'coming',
#   'to',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'for',
#   'education',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'scope',
#   'of',
#   'material',
#   'science',
#   'engineering',
#   '?'],
#  ['as',
#   'a',
#   'practising',
#   'financial',
#   'planner',
#   'in',
#   'india',
#   ',',
#   'how',
#   'much',
#   'have',
#   'you',
#   'been',
#   'able',
#   'to',
#   'make',
#   'in',
#   'terms',
#   'of',
#   'advisory',
#   'fee',
#   'alone',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'digital',
#   'marketing',
#   'company',
#   'in',
#   'pune',
#   '?'],
#  ['what',
#   'stats',
#   'prove',
#   'that',
#   'after',
#   'school',
#   'activities',
#   'combat',
#   'the',
#   'achievement',
#   'gap',
#   'and',
#   'promote',
#   'college',
#   'admissions',
#   '?'],
#  ['how', 'do', 'i', 'pronounce', 'òló', '?'],
#  ['i',
#   'have',
#   'not',
#   'paid',
#   'amount',
#   'for',
#   'taking',
#   'parents',
#   'in',
#   'tu',
#   'convocation',
#   ',',
#   'can',
#   'i',
#   'take',
#   'them',
#   '?'],
#  ['opportunities', 'after', 'phd', 'in', 'sweden', 'in', 'medicine', '?'],
#  ['what',
#   'are',
#   'the',
#   'automobile',
#   'projects',
#   'related',
#   'to',
#   'design',
#   'and',
#   'analysis',
#   'of',
#   'automobile',
#   'part',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'basic',
#   'computer',
#   'knowledge',
#   'that',
#   'everyone',
#   'should',
#   'know',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'most',
#   'well',
#   'known',
#   'start',
#   '-',
#   'up',
#   'or',
#   'venture',
#   'capital',
#   'firms',
#   '?'],
#  ['which',
#   'are',
#   'the',
#   'best',
#   'colleges',
#   'in',
#   'usa',
#   'for',
#   'aerospace',
#   'engineering',
#   '?'],
#  ['why',
#   'are',
#   'some',
#   'items',
#   'made',
#   'of',
#   'wool',
#   'so',
#   'itchy',
#   ',',
#   'but',
#   'others',
#   'soft',
#   '?'],
#  ['how',
#   'do',
#   'people',
#   'get',
#   'obese',
#   '?',
#   'do',
#   'they',
#   'eat',
#   'a',
#   'lot',
#   'more',
#   'than',
#   'the',
#   'average',
#   'person',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'get',
#   'wireless',
#   'internet',
#   'for',
#   'a',
#   'desktop',
#   'computer',
#   '?'],
#  ['what', 'is', 'your', 'favorite', 'song', 'at', 'the', 'moment', '?'],
#  ['can', 'cancer', 'be', 'cured', 'by', 'healing', '?'],
#  ['what', 'kind', 'of', 'pens', 'write', 'much', 'better', '?'],
#  ['why',
#   'men',
#   'don',
#   "'",
#   't',
#   'take',
#   'divorced',
#   'woman',
#   'seriously',
#   '?'],
#  ['can', 'we', 'trust', 'chegg', '?', 'did', 'anybody', 'got', 'paid', '?'],
#  ['which',
#   'is',
#   'better',
#   ',',
#   '5',
#   'gb',
#   'ram',
#   'with',
#   'core',
#   'i3',
#   'or',
#   '2',
#   'gb',
#   'ram',
#   'with',
#   'i5',
#   'processor',
#   'for',
#   'android',
#   'studio',
#   '?'],
#  ['have', 'you', 'ever', 'changed', 'a', 'deeply', 'held', 'opinion', '?'],
#  ['what', 'is', 'depersonalization', 'disorder', '?'],
#  ['why',
#   'can',
#   "'",
#   't',
#   'you',
#   'use',
#   'wifi',
#   'while',
#   'running',
#   'a',
#   'wifi',
#   'hotspot',
#   '?'],
#  ['what', 'is', 'the', 'best', 'lg', 'g3', 'app', '?'],
#  ['what',
#   'are',
#   'the',
#   'expectations',
#   'of',
#   'indian',
#   'women',
#   'from',
#   'their',
#   'partners',
#   'during',
#   'sex',
#   '?'],
#  ['what',
#   'is',
#   'your',
#   'review',
#   'of',
#   'the',
#   'story',
#   'of',
#   'my',
#   'experiments',
#   'with',
#   'truth',
#   '(',
#   'book',
#   ')',
#   'by',
#   'mahatma',
#   'gandhi',
#   '?'],
#  ['what', 'is', 'the', 'most', 'beautiful', 'scandinavian', 'country', '?'],
#  ['where', 'can', 'i', 'download', 'a', 'free', 'ebook', 'in', 'french', '?'],
#  ['what',
#   'is',
#   'something',
#   'that',
#   'you',
#   'know',
#   'that',
#   'i',
#   'don',
#   "'",
#   't',
#   '?'],
#  ['how',
#   'did',
#   'the',
#   'academy',
#   'awards',
#   'come',
#   'to',
#   'be',
#   'called',
#   '"',
#   'the',
#   'oscars',
#   '"?'],
#  ['does', 'the', 'percy', 'jackson', 'movie', 'suck', '?'],
#  ['what',
#   'is',
#   'the',
#   'easy',
#   'way',
#   'to',
#   'use',
#   'a',
#   'delhi',
#   'bike',
#   'in',
#   'hyderabad',
#   '?'],
#  ['was',
#   'muhammed',
#   'a',
#   'narcissist',
#   'who',
#   'used',
#   'to',
#   'receive',
#   'convenient',
#   'revelations',
#   'for',
#   'his',
#   'benefit',
#   '?'],
#  ['what', 'is', 'the', 'force', 'of', 'a', 'wolf', 'bite', '?'],
#  ['how',
#   'do',
#   'you',
#   'use',
#   'the',
#   'slack',
#   'tool',
#   'for',
#   'team',
#   'communication',
#   '?',
#   'what',
#   'pain',
#   'points',
#   'is',
#   'it',
#   'solving',
#   'for',
#   'you',
#   '?',
#   'how',
#   'do',
#   'you',
#   'share',
#   'files',
#   'with',
#   'slack',
#   'for',
#   'team',
#   'review',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'intermediate',
#   'value',
#   'theorem',
#   '?',
#   'how',
#   'do',
#   'you',
#   'find',
#   'it',
#   '?'],
#  ['what',
#   'is',
#   'meant',
#   'by',
#   'mainstream',
#   'culture',
#   'and',
#   'what',
#   'would',
#   'be',
#   'a',
#   'noteworthy',
#   'example',
#   'of',
#   'it',
#   '?'],
#  ['what',
#   'causes',
#   'the',
#   'underside',
#   'of',
#   'my',
#   'eye',
#   'to',
#   'twitch',
#   '?'],
#  ['does',
#   'santa',
#   'live',
#   'at',
#   'the',
#   'north',
#   'pole',
#   ',',
#   'or',
#   'was',
#   'there',
#   'really',
#   'a',
#   'mandela',
#   'effect',
#   'that',
#   'moved',
#   'him',
#   'to',
#   'finland',
#   '?'],
#  ['what', 'are', 'the', 'main', 'components', 'of', 'a', 'cologne', '?'],
#  ['did', 'noam', 'chomsky', 'ever', 'meet', 'bertrand', 'russell', '?'],
#  ['i',
#   "'",
#   'm',
#   'a',
#   '23',
#   'year',
#   'old',
#   'boy',
#   'with',
#   '58',
#   'kgs',
#   'weight',
#   'and',
#   'my',
#   'height',
#   'is',
#   '168',
#   'cms',
#   '.',
#   'do',
#   'i',
#   'still',
#   'have',
#   'a',
#   'chance',
#   'to',
#   'increase',
#   'my',
#   'height',
#   '?',
#   'if',
#   'yes',
#   ',',
#   'what',
#   'food',
#   'habits',
#   'should',
#   'i',
#   'follow',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'calculate',
#   'the',
#   'required',
#   'length',
#   'of',
#   'a',
#   'water',
#   'filled',
#   'pipe',
#   'that',
#   'is',
#   'gravity',
#   'fed',
#   'into',
#   'a',
#   'container',
#   '?',
#   'i',
#   "'",
#   'd',
#   'want',
#   'to',
#   'avoid',
#   'overfilling',
#   'the',
#   'container',
#   '.'],
#  ['how',
#   'do',
#   'i',
#   'keep',
#   'myself',
#   'motivated',
#   'during',
#   'hard',
#   'times',
#   '?'],
#  ['is', 'drinking', 'redbull', 'bad', 'for', 'health', '?'],
#  ['which', 'are', 'best', 'wifi', 'devices', '?'],
#  ['which', 'is', 'best', 'phone', 'under', '12k', '?'],
#  ['as',
#   'an',
#   'engineering',
#   'student',
#   'who',
#   'loves',
#   'science',
#   'but',
#   'is',
#   'coming',
#   'to',
#   'hate',
#   'engineering',
#   ',',
#   'what',
#   'possible',
#   'cure',
#   'do',
#   'i',
#   'have',
#   '?'],
#  ['how',
#   'is',
#   'your',
#   'jet',
#   'black',
#   'iphone',
#   '7',
#   'holding',
#   'up',
#   'against',
#   'scratches',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'convert',
#   'a',
#   'kolkata',
#   'registration',
#   'privately',
#   'owned',
#   'car',
#   'to',
#   'commercial',
#   'one',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'tips',
#   'for',
#   'investing',
#   'in',
#   'an',
#   'airbnb',
#   'property',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'expensive',
#   'phone',
#   'in',
#   'the',
#   'world',
#   '?'],
#  ['i',
#   'sent',
#   'a',
#   'message',
#   'in',
#   'whatsapp',
#   '.',
#   'it',
#   'says',
#   'sent',
#   ',',
#   'not',
#   'delivered',
#   '.',
#   'was',
#   'it',
#   'seen',
#   '?'],
#  ['what', 'are', 'some', 'good', 'early', 'morning', 'habits', '?'],
#  ['which', 'custom', 'rom', 'is', 'best', '?'],
#  ['does',
#   'whatsapp',
#   'web',
#   'work',
#   'even',
#   'if',
#   'the',
#   'computer',
#   'and',
#   'the',
#   'phone',
#   'are',
#   'kilometers',
#   'away',
#   '?',
#   'is',
#   'an',
#   'internet',
#   'connection',
#   'the',
#   'only',
#   'requirement',
#   '?'],
#  ['how', 'do', 'i', 'hit', 'big', 'shots', 'in', 'cricket', '?'],
#  ['i',
#   'am',
#   'a',
#   'female',
#   'capricorn',
#   'sun',
#   'sign',
#   ',',
#   'cancer',
#   'moon',
#   'sign',
#   'and',
#   'libra',
#   'rising',
#   'star',
#   '.',
#   'can',
#   'you',
#   'guess',
#   'what',
#   'i',
#   "'",
#   'm',
#   'like',
#   '?'],
#  ['can', 'i', 'find', 'some', 'answers', 'to', 'etg', 'testing', '?'],
#  ['what', 'are', 'some', 'examples', 'of', 'monopolies', 'in', 'india', '?'],
#  ['what', 'are', 'the', 'pros', '&', 'cons', 'of', 'having', 'children', '?'],
#  ['what', 'does', 'stack', 'overflow', 'lack', '?'],
#  ['how', 'can', 'i', 'find', 'a', 'pro', 'bono', 'lawyer', '?'],
#  ['two', 'bank', 'accounts', 'in', 'same', 'bank', '?'],
#  ['what', 'do', 'you', 'think', 'this', 'painting', 'means', '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'workouts',
#   'for',
#   'building',
#   'back',
#   'muscles',
#   '?'],
#  ['if',
#   'america',
#   'were',
#   'attacked',
#   'by',
#   '10',
#   'million',
#   'foreign',
#   'troops',
#   ',',
#   'could',
#   'they',
#   'handle',
#   'it',
#   '?',
#   'if',
#   'not',
#   'how',
#   'long',
#   'would',
#   'they',
#   'have',
#   'to',
#   'wait',
#   'for',
#   'help',
#   'to',
#   'arrive',
#   '?'],
#  ['are',
#   'there',
#   'any',
#   'alternative',
#   'question',
#   'and',
#   'answer',
#   'websites',
#   'to',
#   'quora',
#   '?'],
#  ['how', 'do', 'we', 'observe', 'planets', 'with', 'radio', 'telescopes', '?'],
#  ['is',
#   'there',
#   'any',
#   'theory',
#   'that',
#   'explains',
#   'that',
#   'demonic',
#   'possessions',
#   'are',
#   'some',
#   'invention',
#   'for',
#   'making',
#   'people',
#   'get',
#   'interested',
#   'in',
#   'religion',
#   '?'],
#  ['do', 'i', 'have', 'to', 'wear', 'a', 'sports', 'bra', 'to', 'gym', '?'],
#  ['what',
#   'are',
#   'personality',
#   'types',
#   'and',
#   'disorders',
#   'that',
#   'make',
#   'a',
#   'person',
#   'unable',
#   'to',
#   'feel',
#   'intimacy',
#   'and',
#   'impulse',
#   'to',
#   'limit',
#   'socializing',
#   'and',
#   'personal',
#   'relationships',
#   '?'],
#  ['if',
#   'earth',
#   'had',
#   'no',
#   'atmosphere',
#   'would',
#   'the',
#   'sky',
#   'appear',
#   'black',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'coaching',
#   'for',
#   'medical',
#   'entrance',
#   'in',
#   'nagpur',
#   '?'],
#  ['which',
#   'books',
#   'do',
#   'you',
#   'recommend',
#   'for',
#   'the',
#   'ca',
#   'ipcc',
#   'for',
#   'both',
#   'groups',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'pursue',
#   'journalism',
#   'after',
#   'my',
#   'b',
#   '.',
#   'tech',
#   '.',
#   'degree',
#   '?'],
#  ['how', 'come', 'all', 'countries', 'are', 'in', 'debt', '?'],
#  ['what', '’', 's', 'your', 'creative', 'process', '?'],
#  ['how',
#   'did',
#   'you',
#   'honestly',
#   'feel',
#   'finding',
#   'out',
#   'you',
#   'had',
#   'been',
#   'cheated',
#   'on',
#   'and',
#   'has',
#   'it',
#   'changed',
#   'you',
#   '?'],
#  ['which', 'are', 'the', 'rarest', 'world', 'war', 'pictures', '?'],
#  ['how',
#   'do',
#   'you',
#   'cook',
#   'a',
#   'chicken',
#   'breast',
#   'in',
#   'a',
#   'oven',
#   '?'],
#  ['why',
#   'do',
#   'indians',
#   'spend',
#   'a',
#   'lot',
#   'of',
#   'money',
#   'on',
#   'marriage',
#   ',',
#   'rather',
#   'than',
#   'americans',
#   'or',
#   'europeans',
#   '?'],
#  ['should', 'we', 'all', 'buy', 'apple', 'stock', 'now', '?'],
#  ['is',
#   'there',
#   'really',
#   'a',
#   'chip',
#   'embedded',
#   'in',
#   'the',
#   'new',
#   'rupees',
#   '2000',
#   'note',
#   '?'],
#  ['is',
#   'there',
#   'a',
#   'difference',
#   'in',
#   'feeling',
#   'versus',
#   'measuring',
#   'progress',
#   'in',
#   'actually',
#   'making',
#   'progress',
#   '?'],
#  ['how', 'do', 'i', 'contact', 'airbnb', 'customer', 'support', '?'],
#  ['is', 'mcom', 'worth', 'doing', 'from', 'srcc', '?'],
#  ['what',
#   'are',
#   'the',
#   'dangers',
#   'of',
#   'taking',
#   'valium',
#   'and',
#   'percocet',
#   'at',
#   'the',
#   'same',
#   'time',
#   '?'],
#  ['what', 'is', 'the', 'best', 'glue', 'for', 'shoe', 'repair', '?'],
#  ['my',
#   'percentage',
#   'is',
#   '62',
#   '%',
#   'in',
#   'b',
#   '.',
#   'tech',
#   '.',
#   'i',
#   'want',
#   'to',
#   'join',
#   'into',
#   'niit',
#   'institute',
#   '.',
#   'do',
#   'they',
#   'provide',
#   'me',
#   'a',
#   'job',
#   'in',
#   'good',
#   'mnc',
#   "'",
#   's',
#   'with',
#   'that',
#   'percentage',
#   '.',
#   'how',
#   'worthytojoin',
#   'niit',
#   '?'],
#  ['how',
#   'can',
#   'an',
#   'unhealthy',
#   'woman',
#   'like',
#   'hillary',
#   'become',
#   'the',
#   'president',
#   'of',
#   'the',
#   'usa',
#   '?',
#   'dont',
#   'her',
#   'supporters',
#   'know',
#   'that',
#   'she',
#   'is',
#   'terribly',
#   'ill',
#   '?'],
#  ['amazon',
#   'interview',
#   ':',
#   'what',
#   'is',
#   'the',
#   'best',
#   'answer',
#   'to',
#   'the',
#   'question',
#   '"',
#   'why',
#   'amazon',
#   '?"?'],
#  ['what', 'does', 'a', '.', 'd', 'stand', 'for', '?'],
#  ['how',
#   'do',
#   'you',
#   'cut',
#   'line',
#   'externally',
#   'and',
#   'internally',
#   'in',
#   'maths',
#   '?'],
#  ['can',
#   'we',
#   'prepare',
#   'for',
#   'the',
#   'jee',
#   'main',
#   'in',
#   'the',
#   'last',
#   '4',
#   'months',
#   'and',
#   'get',
#   '180',
#   'or',
#   'more',
#   '?',
#   'i',
#   'have',
#   'studied',
#   'well',
#   'but',
#   'low',
#   'on',
#   'confidence'],
#  ['what',
#   'will',
#   'happen',
#   'to',
#   'a',
#   'person',
#   'who',
#   'has',
#   'bot',
#   'opposite',
#   'phobia',
#   'apeirophobia',
#   'and',
#   'thanatophobia',
#   '?'],
#  ['will',
#   'slow',
#   'and',
#   'smooth',
#   'driving',
#   'of',
#   'two',
#   'wheeler',
#   'in',
#   'indian',
#   'road',
#   'conditions',
#   'prevent',
#   'back',
#   '/',
#   'spine',
#   'related',
#   'problems',
#   '?'],
#  ['how', 'should', 'i', 'live', 'my', 'life', '?'],
#  ['how', 'do', 'i', 'overcome', 'pimples', 'due', 'to', 'pcod', '?'],
#  ['what', 'will', 'be', 'the', 'journal', 'entries', 'for', 'discount', '?'],
#  ['what',
#   'is',
#   'the',
#   'maximum',
#   'number',
#   'of',
#   'times',
#   'you',
#   'can',
#   'fold',
#   'a',
#   'piece',
#   'of',
#   'paper',
#   '?'],
#  ['as',
#   'shia',
#   'is',
#   'a',
#   'denomination',
#   'of',
#   'islam',
#   ',',
#   'why',
#   'is',
#   'the',
#   'shia',
#   'majority',
#   'iraq',
#   'being',
#   'opposed',
#   'by',
#   'isis',
#   '(',
#   'islamic',
#   'state',
#   'of',
#   'iraq',
#   'and',
#   'syria',
#   ')?'],
#  ['how', 'can', 'approach', 'guy', 'i', 'like', '?'],
#  ['can',
#   'hillary',
#   'clinton',
#   'pardon',
#   'herself',
#   'if',
#   'she',
#   'is',
#   'elected',
#   'as',
#   'president',
#   '?'],
#  ['is',
#   'it',
#   'too',
#   'late',
#   'for',
#   'any',
#   'age',
#   'person',
#   'to',
#   'learn',
#   'computer',
#   'programing',
#   '?'],
#  ['i',
#   'am',
#   'doing',
#   'bachelors',
#   'in',
#   'computer',
#   'science',
#   '.',
#   'i',
#   'will',
#   'be',
#   'done',
#   'with',
#   'my',
#   '4th',
#   'semester',
#   'in',
#   'few',
#   'days',
#   '.',
#   'i',
#   'have',
#   '3',
#   'month',
#   'of',
#   'summer',
#   'vacation',
#   'ahead',
#   ',',
#   'what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'i',
#   'can',
#   'utilize',
#   'these',
#   '3',
#   'months',
#   'so',
#   'i',
#   'can',
#   'land',
#   'a',
#   'good',
#   'internship',
#   '/',
#   'job',
#   'in',
#   'future',
#   'at',
#   'a',
#   'top',
#   'notch',
#   'company',
#   'like',
#   'microsoft',
#   ',',
#   'google',
#   ',',
#   'facebook',
#   'etc',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'point',
#   'and',
#   'shoot',
#   'camera',
#   'under',
#   '7k',
#   '?'],
#  ['how', 'do', 'i', 'research', 'for', 'mun', '?'],
#  ['how',
#   'do',
#   'you',
#   'know',
#   'if',
#   'your',
#   'boyfriend',
#   'actually',
#   'loves',
#   'you',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'books',
#   'required',
#   'for',
#   'b',
#   '.',
#   'tech',
#   'it',
#   'first',
#   'year',
#   '?'],
#  ['what', 'are', 'some', 'spanish', 'inventions', 'we', 'use', 'daily', '?'],
#  ['how',
#   'will',
#   'you',
#   'ensure',
#   'that',
#   'that',
#   'the',
#   'next',
#   'military',
#   'intervention',
#   'by',
#   'us',
#   'is',
#   'a',
#   'genuine',
#   'one',
#   '?'],
#  ['which', 'human', 'race', 'is', 'most', 'evolved', '?'],
#  ['what',
#   'is',
#   'a',
#   'good',
#   'coaching',
#   'institute',
#   'for',
#   'cfa',
#   'in',
#   'chennai',
#   '?'],
#  ['is',
#   'there',
#   'a',
#   'free',
#   'version',
#   'of',
#   'vmware',
#   'vsphere',
#   'hypervisor',
#   '?',
#   'if',
#   'not',
#   ',',
#   'which',
#   'are',
#   'some',
#   'effective',
#   'alternatives',
#   '?'],
#  ['what', 'does', 'the', '12th', 'amendment', 'mean', '?'],
#  ['how',
#   'would',
#   'you',
#   'describe',
#   'india',
#   'in',
#   'one',
#   'sentence',
#   'to',
#   'someone',
#   'from',
#   'north',
#   'america',
#   'who',
#   'has',
#   'never',
#   'been',
#   'to',
#   'india',
#   '?'],
#  ['which',
#   'book',
#   'is',
#   'better',
#   'for',
#   'understand',
#   'basics',
#   'sterength',
#   'of',
#   'material',
#   '?'],
#  ['what',
#   'does',
#   'shakespeare',
#   'mean',
#   'by',
#   "'",
#   'a',
#   'little',
#   'more',
#   'than',
#   'kin',
#   ',',
#   'and',
#   'less',
#   'than',
#   'kind',
#   "'?"],
#  ['can',
#   'eating',
#   'boiled',
#   'egg',
#   'or',
#   'omelette',
#   'cause',
#   'bird',
#   'flu',
#   '?'],
#  ['should',
#   'i',
#   'try',
#   'to',
#   'find',
#   'out',
#   'who',
#   'my',
#   'birth',
#   'father',
#   'is',
#   '?'],
#  ['how',
#   'much',
#   'initial',
#   'capital',
#   'would',
#   'you',
#   'need',
#   'to',
#   'become',
#   'an',
#   'investor',
#   'successfully',
#   'like',
#   'warren',
#   'buffet',
#   'if',
#   'you',
#   'are',
#   '21',
#   '?'],
#  ['why', 'is', 'the', 'singapore', 'education', 'system', 'so', 'good', '?'],
#  ['is', 'your', 'education', 'worth', 'it', '?'],
#  ['would',
#   'it',
#   'be',
#   'feasible',
#   'to',
#   'genetically',
#   'engineer',
#   'humans',
#   'to',
#   'have',
#   'two',
#   'hearts',
#   '?'],
#  ['has',
#   'any',
#   'us',
#   'presidential',
#   'candidate',
#   'sold',
#   'cabinet',
#   'positions',
#   'in',
#   'his',
#   'administration',
#   'in',
#   'return',
#   'for',
#   'campaign',
#   'contributions',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'north',
#   'indian',
#   'food',
#   'restaurant',
#   'in',
#   'karkardooma',
#   '?'],
#  ['how', 'do', 'you', 'make', 'a', 'bass', 'fish', 'trap', '?'],
#  ['does', 'lime', 'juice', 'go', 'bad', '?'],
#  ['what', 'are', 'disadvantages', 'of', 'a', 'love', 'marriage', '?'],
#  ['can', 'i', 'change', 'my', 'branch', 'in', 'davv', 'indore', '?'],
#  ['how', 'much', 'are', 'diamonds', 'worth', '?'],
#  ['what', 'is', 'a', 'fair', 'startup', 'salary', '?'],
#  ['which', 'are', 'best', 'private', 'medical', 'colleges', '?'],
#  ['what',
#   'are',
#   'the',
#   'lyrics',
#   'for',
#   "'",
#   'what',
#   'is',
#   'love',
#   "?'",
#   'by',
#   'haddaway',
#   '?'],
#  ['if',
#   'you',
#   'throw',
#   'up',
#   'within',
#   '30',
#   'minutes',
#   'of',
#   'eating',
#   ',',
#   'how',
#   'many',
#   'calories',
#   'do',
#   'you',
#   'lose',
#   'of',
#   'the',
#   'food',
#   'you',
#   'ate',
#   '?'],
#  ['how', 'do', 'i', 'participate', 'in', 'splitsvilla', '?'],
#  ['which',
#   'it',
#   'companies',
#   'in',
#   'kolkata',
#   'offer',
#   'internships',
#   'to',
#   'bca',
#   'students',
#   '?'],
#  ['how', 'do', 'i', 'bolster', 'my', 'self', '-', 'esteem', '?'],
#  ['how', 'do', 'i', 'teach', 'a', 'child', 'to', 'read', 'and', 'write', '?'],
#  ['how',
#   'do',
#   'we',
#   'prove',
#   '[',
#   'math',
#   '](',
#   '1',
#   '+\\',
#   'frac',
#   '{',
#   '1',
#   '}{',
#   'n',
#   '})^',
#   'n',
#   '<',
#   '(',
#   '1',
#   '+',
#   '\\',
#   'frac',
#   '{',
#   '1',
#   '}{',
#   'n',
#   '+',
#   '1',
#   '})^{',
#   'n',
#   '+',
#   '1',
#   '}[/',
#   'math',
#   ']?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'inheritance',
#   ',',
#   'encapsulation',
#   'and',
#   'polymorphism',
#   '?'],
#  ['why', 'have', 'i', 'not', 'seen', 'my', 'period', '?'],
#  ['how', 'can', 'i', 'read', 'this', 'time', '?'],
#  ['what',
#   'is',
#   'the',
#   'prescribed',
#   'book',
#   'for',
#   'mechanical',
#   'engineer',
#   'students',
#   'to',
#   'clear',
#   'the',
#   'isro',
#   'scientist',
#   '/',
#   'engineer',
#   'sc',
#   'exam',
#   '?'],
#  ['i',
#   'have',
#   'still',
#   'not',
#   'prepared',
#   'constructions',
#   ',',
#   'locus',
#   'and',
#   'graphs',
#   'in',
#   'maths',
#   '.',
#   'would',
#   'i',
#   'will',
#   'be',
#   'able',
#   'to',
#   'score',
#   '100',
#   'in',
#   'icse',
#   'maths',
#   '?'],
#  ['what',
#   'ethical',
#   'issues',
#   'do',
#   'operators',
#   'of',
#   'restaurant',
#   'need',
#   'to',
#   'be',
#   'aware',
#   'of',
#   '?'],
#  ['how',
#   'much',
#   'money',
#   'are',
#   'artists',
#   'currently',
#   'making',
#   'off',
#   'of',
#   'spotify',
#   '?'],
#  ['which',
#   'episode',
#   'of',
#   'star',
#   'trek',
#   '(',
#   'tos',
#   ')',
#   'features',
#   'slimy',
#   'things',
#   'which',
#   'gets',
#   'itself',
#   'glued',
#   'to',
#   'the',
#   'crew',
#   '?'],
#  ['which',
#   'is',
#   'a',
#   'suitable',
#   'inpatient',
#   'drug',
#   'and',
#   'alcohol',
#   'rehab',
#   'center',
#   'near',
#   'putnam',
#   'county',
#   'in',
#   '?'],
#  ['are', 'a', 'grades', 'enough', 'to', 'get', 'into', 'cambridge', '?'],
#  ['how',
#   'good',
#   'is',
#   'the',
#   '17',
#   'hmr',
#   'rifle',
#   'for',
#   'coyote',
#   'hunting',
#   '?'],
#  ['i',
#   'got',
#   'letter',
#   'of',
#   'intent',
#   'to',
#   'hire',
#   'from',
#   'infosys',
#   '.',
#   'will',
#   'i',
#   'be',
#   'surely',
#   'called',
#   'by',
#   'infosys',
#   '?'],
#  ['how', 'does', 'raspberry', 'pi', 'work', '?'],
#  ['how', 'long', 'does', 'it', 'take', 'to', 'open', 'an', 'llc', '?'],
#  ['what',
#   'is',
#   'your',
#   'opinion',
#   'of',
#   'the',
#   'quote',
#   ':',
#   '"',
#   'most',
#   'people',
#   "'",
#   's',
#   'lives',
#   'are',
#   'a',
#   'direct',
#   'reflection',
#   'of',
#   'the',
#   'expectations',
#   'of',
#   'their',
#   'peer',
#   'group',
#   '"?'],
#  ['scope',
#   'for',
#   'cse',
#   '(',
#   'b',
#   '.',
#   'tech',
#   '/',
#   'b',
#   '.',
#   'e',
#   '.)',
#   'graduates',
#   'to',
#   'get',
#   'foreign',
#   'job',
#   '?',
#   'if',
#   'yes',
#   ',',
#   'then',
#   'how',
#   '?'],
#  ['where',
#   'should',
#   'i',
#   'go',
#   'to',
#   'get',
#   'cheap',
#   'goats',
#   'milk',
#   'in',
#   'the',
#   'uk',
#   '?'],
#  ['i',
#   'am',
#   'an',
#   'arts',
#   'graduate',
#   ',',
#   'can',
#   'do',
#   'rhce',
#   'certification',
#   '.',
#   'and',
#   'get',
#   'a',
#   'job',
#   'in',
#   'india',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'creative',
#   'way',
#   'you',
#   'can',
#   'break',
#   'a',
#   'clock',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'solve',
#   'the',
#   'following',
#   'problem',
#   '?',
#   'is',
#   'it',
#   'possible',
#   'to',
#   'solve',
#   'using',
#   'segment',
#   'trees',
#   '?',
#   'are',
#   'there',
#   'any',
#   'efficient',
#   'methods',
#   '?'],
#  ['what',
#   'can',
#   'i',
#   'use',
#   'to',
#   'host',
#   'a',
#   '1',
#   'table',
#   'database',
#   'that',
#   'will',
#   'be',
#   'used',
#   'by',
#   'a',
#   'mobile',
#   'app',
#   '?'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'declutter',
#   'my',
#   'life',
#   'and',
#   'become',
#   'a',
#   'minimalist',
#   '.',
#   'i',
#   'am',
#   'finding',
#   'it',
#   'i',
#   'very',
#   'difficult',
#   'to',
#   'get',
#   'rid',
#   'of',
#   'stuff',
#   '.',
#   'is',
#   'there',
#   'a',
#   'way',
#   'to',
#   'outsource',
#   'this',
#   '?'],
#  ['how', 'are', 'long', 'distance', 'relationships', 'maintained', '?'],
#  ['how',
#   'many',
#   'worlds',
#   'are',
#   'there',
#   'in',
#   'super',
#   'mario',
#   'bros',
#   '.',
#   'wii',
#   '?'],
#  ['what', 'are', 'examples', 'of', 'brilliant', 'medical', 'strategy', '?'],
#  ['do', 'physical', 'laws', 'change', 'over', 'time', '?'],
#  ['did',
#   'mark',
#   'zuckerberg',
#   'steal',
#   'the',
#   'idea',
#   'of',
#   'facebook',
#   'from',
#   'cameron',
#   'winklevoss',
#   '?'],
#  ['what',
#   'kind',
#   'of',
#   'advanced',
#   'c',
#   '++',
#   'features',
#   'i',
#   'need',
#   'to',
#   'learn',
#   'if',
#   'i',
#   'want',
#   'to',
#   'work',
#   'for',
#   'google',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'activate',
#   'two',
#   'jio',
#   'sims',
#   'in',
#   'one',
#   'phone',
#   '?'],
#  ['what', 'are', 'the', 'ranks', 'in', 'the', 'navy', 'seals', '?'],
#  ['which',
#   'software',
#   'is',
#   'best',
#   'for',
#   'stock',
#   'and',
#   'options',
#   'automated',
#   'trading',
#   'in',
#   'india',
#   '?'],
#  ['what', 'animals', 'begin', 'with', 'the', 'letter', 'x', '?'],
#  ['why',
#   'don',
#   "'",
#   't',
#   'more',
#   'americans',
#   'aspire',
#   'to',
#   'public',
#   'sector',
#   '/',
#   'civil',
#   'service',
#   'jobs',
#   '?'],
#  ['did',
#   'god',
#   'punish',
#   'slave',
#   'master',
#   "'",
#   's',
#   'who',
#   'didn',
#   "'",
#   't',
#   'treat',
#   'their',
#   'slaves',
#   'fairly',
#   '?'],
#  ['which',
#   'two',
#   'bollywood',
#   'actors',
#   'or',
#   'actresses',
#   'most',
#   'resemble',
#   'each',
#   'other',
#   '?'],
#  ['what', 'is', 'the', 'best', 'software', 'company', 'in', 'chennai', '?'],
#  ['in',
#   'american',
#   'history',
#   ',',
#   'has',
#   'any',
#   'republican',
#   'ever',
#   'owned',
#   'a',
#   'slave',
#   '?'],
#  ['how',
#   'one',
#   'should',
#   'begin',
#   'to',
#   'prepare',
#   'for',
#   'iiit',
#   'h',
#   'lateral',
#   'entry',
#   'from',
#   'first',
#   'year',
#   '?'],
#  ['how',
#   'does',
#   'demographic',
#   'momentum',
#   'function',
#   'in',
#   'human',
#   'geography',
#   '?'],
#  ['i',
#   "'",
#   'm',
#   'a',
#   'self',
#   'trained',
#   'amateur',
#   'artist',
#   'from',
#   'engineering',
#   'background',
#   '.',
#   'currently',
#   'i',
#   "'",
#   'm',
#   'working',
#   'for',
#   'cts',
#   'and',
#   'the',
#   'job',
#   'is',
#   'very',
#   'frustrating',
#   'for',
#   'me',
#   '.',
#   'how',
#   'can',
#   'i',
#   'breakfree',
#   'from',
#   'my',
#   'dull',
#   'job',
#   'and',
#   'pursue',
#   'a',
#   'career',
#   'in',
#   'art',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'craziest',
#   'moment',
#   'of',
#   'your',
#   'college',
#   'life',
#   '?'],
#  ['should', 'i', 'get', 'an', 'mba', 'in', 'agribusiness', '?'],
#  ['why',
#   'do',
#   'i',
#   'sometimes',
#   'feel',
#   'like',
#   'the',
#   'people',
#   'i',
#   'know',
#   'are',
#   'watching',
#   'me',
#   '?'],
#  ['how', 'do', 'i', 'use', 'bitcoin', 'in', 'singapore', '?'],
#  ['what',
#   'news',
#   'sources',
#   'do',
#   'diplomats',
#   'read',
#   'to',
#   'get',
#   'global',
#   ',',
#   'macro',
#   'perspectives',
#   '?'],
#  ['why',
#   'am',
#   'i',
#   'feeling',
#   'uncomfortable',
#   'to',
#   'make',
#   'eye',
#   'contact',
#   '?'],
#  ['how', 'is', 'dtu', '?'],
#  ['as',
#   'a',
#   'foreigner',
#   ',',
#   'what',
#   'things',
#   'do',
#   'you',
#   'dislike',
#   'about',
#   'america',
#   ',',
#   'or',
#   'american',
#   'people',
#   '?'],
#  ['i',
#   'am',
#   'in',
#   'eighth',
#   'grade',
#   'and',
#   'i',
#   'got',
#   'a',
#   '1700',
#   '+',
#   'on',
#   'my',
#   'lexile',
#   'test',
#   '.',
#   'is',
#   'this',
#   'good',
#   'or',
#   'bad',
#   'and',
#   'what',
#   'does',
#   'it',
#   'mean',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'emerging',
#   'storytelling',
#   'formats',
#   '?'],
#  ['how', 'do', 'i', 'become', 'a', 'good', 'teacher', '/', 'tutor', '?'],
#  ['what', 'is', 'the', 'best', 'belgian', 'beer', '?'],
#  ['what',
#   'were',
#   'the',
#   'origins',
#   'of',
#   'the',
#   'first',
#   'languages',
#   'and',
#   'what',
#   'were',
#   'these',
#   'languages',
#   '?'],
#  ['if',
#   'north',
#   'korea',
#   'were',
#   'to',
#   'attack',
#   'south',
#   'korea',
#   'suddenly',
#   ',',
#   'how',
#   'would',
#   'the',
#   'latter',
#   'with',
#   'its',
#   'ally',
#   ',',
#   'usa',
#   ',',
#   'defend',
#   'itself',
#   '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'if',
#   'a',
#   'website',
#   'is',
#   'hosted',
#   'on',
#   'a',
#   'load',
#   'balanced',
#   'web',
#   'server',
#   'and',
#   'that',
#   'sticky',
#   'sessions',
#   'would',
#   'have',
#   'to',
#   'be',
#   'enabled',
#   'on',
#   'the',
#   'load',
#   'balancers',
#   'and',
#   'that',
#   'session',
#   'checks',
#   'would',
#   'have',
#   'to',
#   'be',
#   'done',
#   'on',
#   'page',
#   'loads',
#   '?'],
#  ['why',
#   'do',
#   'i',
#   'smile',
#   'even',
#   'when',
#   'i',
#   'don',
#   "'",
#   't',
#   'want',
#   'to',
#   '?'],
#  ['what',
#   'do',
#   '"',
#   'mobile',
#   '"',
#   'and',
#   '"',
#   'home',
#   '"',
#   'mean',
#   'on',
#   'the',
#   'whatsapp',
#   'contacts',
#   'page',
#   '?'],
#  ['i',
#   'feel',
#   'like',
#   'disappearing',
#   'from',
#   'this',
#   'world',
#   '?',
#   'no',
#   'money',
#   '/',
#   'fame',
#   '/',
#   'career',
#   'seems',
#   'lucrative',
#   'enough',
#   'to',
#   'stay',
#   'back',
#   '.',
#   'does',
#   'anyone',
#   'feel',
#   'the',
#   'same',
#   '?'],
#  ['does', 'girls', 'like', 'big', 'penis', '?'],
#  ['is', 'it', 'illegal', 'to', 'send', 'cash', 'through', 'the', 'mail', '?'],
#  ['why',
#   'do',
#   'mother',
#   'cats',
#   'sometimes',
#   'eat',
#   'their',
#   'own',
#   'kittens',
#   '?'],
#  ['i',
#   'am',
#   'planning',
#   'to',
#   'learn',
#   'a',
#   'framework',
#   '-',
#   'oaf',
#   'or',
#   'adf',
#   '?',
#   'any',
#   'suggestions',
#   'which',
#   'is',
#   'better',
#   'for',
#   'present',
#   'situation',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'love',
#   'story',
#   'movies',
#   'just',
#   'as',
#   'titanic',
#   '?'],
#  ['what', 'are', 'the', 'pros', 'and', 'cons', 'of', 'shopify', '?'],
#  ['what', "'", 's', 'the', 'inverse', 'function', '?'],
#  ['how', 'do', 'i', 'copyright', 'a', 'logo', '?'],
#  ['what',
#   'was',
#   'it',
#   'like',
#   'to',
#   'travel',
#   'on',
#   'board',
#   'a',
#   'concorde',
#   '?'],
#  ['how', 'can', 'i', 'live', 'a', 'simple', 'life', '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'when',
#   'a',
#   'girl',
#   'grabs',
#   'your',
#   'erect',
#   'penis',
#   '?'],
#  ['which',
#   'countries',
#   'have',
#   'the',
#   'tradition',
#   'of',
#   'taking',
#   'off',
#   'shoes',
#   'before',
#   'you',
#   'enter',
#   'a',
#   'home',
#   '?'],
#  ['why', 'is', 'a', 'university', 'degree', 'so', 'important', '?'],
#  ['what', 'is', 'mentoring', '?'],
#  ['how',
#   'do',
#   'you',
#   'cope',
#   'with',
#   'being',
#   'scammed',
#   'and',
#   'losing',
#   'a',
#   'lot',
#   'of',
#   'money',
#   'knowing',
#   'you',
#   'will',
#   'not',
#   'get',
#   'it',
#   'back',
#   '?'],
#  ['how', 'much', 'does', 'starting', 'a', 'website', 'cost', '?'],
#  ['can', 'a', 'foreigner', 'buy', 'american', 'mutual', 'funds', '?'],
#  ['why',
#   'is',
#   'my',
#   'google',
#   'in',
#   'a',
#   'foreign',
#   'language',
#   'on',
#   'safari',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'app',
#   'to',
#   'block',
#   'unwanted',
#   'voice',
#   'messages',
#   'and',
#   'calls',
#   '?'],
#  ['is', 'taiwan', 'part', 'of', 'or', 'separate', 'from', 'china', '?'],
#  ['is', 'playing', 'chess', 'waste', 'of', 'time', '?'],
#  ['is', 'nude', 'photography', 'considered', 'objectification', '?'],
#  ['what',
#   'is',
#   'buried',
#   'or',
#   'was',
#   'buried',
#   'under',
#   'solomon',
#   "'",
#   's',
#   'temple',
#   '?'],
#  ['between',
#   'mac',
#   'os',
#   'and',
#   'windows',
#   ',',
#   'which',
#   'os',
#   'should',
#   'i',
#   'chose',
#   'as',
#   'a',
#   'web',
#   'developer',
#   '?'],
#  ['do', 'shock', 'collars', 'work', 'on', 'dogs', '?'],
#  ['why', 'is', 'the', 'yale', 'art', 'website', 'so', 'bad', '?'],
#  ['how',
#   'has',
#   'your',
#   'lifestyle',
#   'changed',
#   'before',
#   'and',
#   'after',
#   'using',
#   'quora',
#   '?'],
#  ['how', 'do', 'i', 'choose', 'a', 'topic', 'for', 'my', 'blog', '?'],
#  ['what',
#   'exactly',
#   'does',
#   'borderline',
#   'personality',
#   'disorder',
#   'mean',
#   '?',
#   'and',
#   'what',
#   'are',
#   'the',
#   'symptoms',
#   '?'],
#  ['why', 'do', 'i', 'enjoy', 'hurting', 'myself', '?'],
#  ['how', 'do', 'you', 'clean', 'out', 'a', 'catalytic', 'converter', '?'],
#  ['what', 'are', 'best', 'things', 'to', 'be', 'learned', 'in', 'life', '?'],
#  ['do',
#   'girls',
#   'stop',
#   'growing',
#   'in',
#   'height',
#   'once',
#   'they',
#   'get',
#   'their',
#   'periods',
#   '?'],
#  ['where',
#   'could',
#   'i',
#   'find',
#   'a',
#   'best',
#   'escort',
#   'agency',
#   'in',
#   'malaysia',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'ias',
#   'coaching',
#   'centre',
#   'in',
#   'trivandrum',
#   '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'when',
#   'a',
#   'girl',
#   'says',
#   "'",
#   'you',
#   "'",
#   're',
#   'so',
#   'affectionate',
#   ".'?"],
#  ['why', 'is', 'virginity', 'a', 'big', 'deal', 'in', 'society', '?'],
#  ['what',
#   'is',
#   'the',
#   'character',
#   'or',
#   'theory',
#   'that',
#   'you',
#   'believe',
#   'to',
#   'be',
#   'true',
#   'while',
#   'most',
#   'people',
#   'don',
#   "'",
#   't',
#   '?',
#   'why',
#   '?'],
#  ['why', 'do', 'i', 'get', 'bored', 'easily', '?'],
#  ['what', 'should', 'i', 'learn', 'php', 'or', '.', 'net', '?'],
#  ['what', 'is', 'the', 'virgin', '?'],
#  ['are', 'turks', 'and', 'azerbaijanis', 'considered', 'white', '?'],
#  ['what', 'should', 'i', 'do', 'with', 'my', 'career', 'life', '?'],
#  ['what',
#   'do',
#   'you',
#   'think',
#   'of',
#   'the',
#   'reliance',
#   'jio',
#   'ad',
#   'featuring',
#   'prime',
#   'minister',
#   'modi',
#   '?',
#   'do',
#   'you',
#   'think',
#   'its',
#   'legally',
#   'or',
#   'ethically',
#   'correct',
#   'to',
#   'do',
#   'so',
#   '?'],
#  ['how',
#   'does',
#   'one',
#   'train',
#   'to',
#   'become',
#   'a',
#   'world',
#   'champion',
#   'pole',
#   'dancer',
#   '?'],
#  ['how',
#   'do',
#   'people',
#   'feel',
#   'when',
#   'the',
#   'borders',
#   'of',
#   'their',
#   'country',
#   'change',
#   '?'],
#  ['how',
#   'does',
#   'mypromovideo',
#   'of',
#   'youtube',
#   'make',
#   'there',
#   'animation',
#   '?'],
#  ['do', 'lizards', 'feel', 'thirsty', '?'],
#  ['scs',
#   ':',
#   'what',
#   'would',
#   'happen',
#   'to',
#   'the',
#   'appointment',
#   'of',
#   'arbitrators',
#   'made',
#   'by',
#   'the',
#   'president',
#   'itlos',
#   'if',
#   'china',
#   'did',
#   'not',
#   'approve',
#   'it',
#   '?'],
#  ['my',
#   'husband',
#   'was',
#   'so',
#   'mean',
#   'for',
#   'most',
#   'our',
#   '20',
#   'yr',
#   'relationship',
#   'but',
#   'the',
#   'past',
#   'couple',
#   'of',
#   'years',
#   ',',
#   'he',
#   "'",
#   's',
#   'started',
#   'being',
#   'nice',
#   '.',
#   'how',
#   'can',
#   'i',
#   'get',
#   'past',
#   'the',
#   'painful',
#   'memories',
#   '?'],
#  ['what', 'are', 'the', 'best', 'programming', 'practice', 'sites', '?'],
#  ['what', 'are', 'compulsory', 'acts', 'of', 'worship', 'in', 'islam', '?'],
#  ['what',
#   'would',
#   'be',
#   'your',
#   'advice',
#   'to',
#   'those',
#   'who',
#   'want',
#   'to',
#   'build',
#   'a',
#   'social',
#   'enterprise',
#   'but',
#   'have',
#   'no',
#   'prior',
#   'background',
#   'in',
#   'the',
#   'field',
#   'nor',
#   'an',
#   'advanced',
#   'education',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'achieve',
#   'the',
#   'freezing',
#   'point',
#   'of',
#   'hexane',
#   '?',
#   'how',
#   'does',
#   'it',
#   'compare',
#   'to',
#   'methane',
#   '?'],
#  ['would',
#   'you',
#   'trust',
#   'meth',
#   'users',
#   'and',
#   '/',
#   'or',
#   'are',
#   '“',
#   'meth',
#   'users',
#   'mean',
#   'and',
#   'selfish',
#   '”',
#   '?'],
#  ['should',
#   'new',
#   'actors',
#   'start',
#   'in',
#   'commercials',
#   'to',
#   'build',
#   'up',
#   'their',
#   'acting',
#   'credits',
#   'then',
#   'focus',
#   'on',
#   'film',
#   '/',
#   'tv',
#   'after',
#   '?'],
#  ['what', 'is', 'lamictal', 'abuse', '?'],
#  ['how',
#   'dangerous',
#   'is',
#   'it',
#   'if',
#   'a',
#   'dog',
#   'eats',
#   'chocolate',
#   'cake',
#   '?'],
#  ['would',
#   'vegans',
#   'view',
#   'animal',
#   'consumption',
#   'as',
#   'morally',
#   'permissible',
#   'if',
#   'the',
#   'animals',
#   'were',
#   'allowed',
#   'a',
#   'full',
#   'life',
#   'and',
#   'only',
#   'consumed',
#   'after',
#   'dying',
#   'from',
#   'natural',
#   'causes',
#   '?'],
#  ['what',
#   'is',
#   'most',
#   'appropriate',
#   'software',
#   'design',
# ...
#   'original',
#   'meaning',
#   'of',
#   '"',
#   'falana',
#   'dimka',
#   '"?'],
#  ['how',
#   'can',
#   'a',
#   'rising',
#   'computer',
#   'science',
#   'student',
#   ',',
#   'who',
#   'has',
#   'had',
#   'no',
#   'prior',
#   'knowledge',
#   'of',
#   'programming',
#   'or',
#   'data',
#   'structures',
#   ',',
#   'learn',
#   'to',
#   'compete',
#   'against',
#   'other',
#   'computer',
#   'science',
#   'students',
#   'with',
#   'years',
#   'of',
#   'experience',
#   '?'],
#  ['is', 'michele', 'obama', 'really', 'a', 'man', '?'],
#  ['how', 'do', 'i', 'flirt', 'with', 'a', 'girl', 'who', 'likes', 'me', '?'],
#  ['can', 'chihuahuas', 'eat', 'peanuts', '?', 'why', 'or', 'why', 'not', '?'],
#  ['for',
#   'how',
#   'long',
#   'will',
#   'donald',
#   'trump',
#   'be',
#   'president',
#   'of',
#   'the',
#   'us',
#   '?'],
#  ['for',
#   'building',
#   'a',
#   'system',
#   'like',
#   'udemy',
#   ',',
#   'coursera',
#   'or',
#   'edx',
#   'can',
#   'one',
#   'use',
#   'an',
#   'available',
#   'off',
#   'the',
#   'shelf',
#   'lms',
#   'or',
#   'have',
#   'this',
#   'custom',
#   'build',
#   'in',
#   'php',
#   'or',
#   'dot',
#   'net',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'tell',
#   'if',
#   'a',
#   'guy',
#   'is',
#   'gay',
#   'and',
#   'is',
#   'interested',
#   'in',
#   'me',
#   '?'],
#  ['what', "'", 's', 'a', 'good', 'distributed', 'queue', '?'],
#  ['how',
#   'do',
#   'i',
#   'get',
#   'a',
#   'job',
#   'in',
#   'whatsapp',
#   'as',
#   'a',
#   'support',
#   'analyst',
#   '?'],
#  ['how', 'do', 'you', 'heal', 'a', 'cut', 'on', 'your', 'gums', '?'],
#  ['why', 'are', 'converse', 'shoes', 'sized', 'so', 'large', '?'],
#  ['who', 'made', 'you', 'realize', 'you', 'were', 'gay', '?'],
#  ['what',
#   'is',
#   'your',
#   'preferred',
#   'combination',
#   'of',
#   'sauces',
#   'in',
#   'subway',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'single',
#   'phase',
#   'and',
#   'three',
#   'phase',
#   'power',
#   '?'],
#  ['what', 'are', 'the', 'components', 'for', 'an', 'online', 'business', '?'],
#  ['why',
#   'does',
#   'a',
#   'girl',
#   'ignore',
#   'you',
#   'when',
#   'she',
#   'knows',
#   'the',
#   'fact',
#   'that',
#   'you',
#   'like',
#   'her',
#   '?'],
#  ['what',
#   'will',
#   'happen',
#   'after',
#   'death',
#   'according',
#   'to',
#   'science',
#   '?'],
#  ['how', 'can', 'i', 'write', 'research', '?'],
#  ['how',
#   'do',
#   'i',
#   'perform',
#   'reverse',
#   'engineering',
#   'in',
#   'pharmaceuticals',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'apply',
#   'for',
#   'pan',
#   'card',
#   'online',
#   ',',
#   'please',
#   'read',
#   'details',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'evidence',
#   'that',
#   'we',
#   'really',
#   'did',
#   'land',
#   'on',
#   'the',
#   'moon',
#   '?'],
#  ['who',
#   'is',
#   'the',
#   'famous',
#   'coder',
#   '"',
#   'trojenguri',
#   '"',
#   'from',
#   'svnit',
#   ',',
#   'surat',
#   '?'],
#  ['why',
#   'is',
#   'frictional',
#   'force',
#   'is',
#   'not',
#   'a',
#   'conservative',
#   'force',
#   '?'],
#  ['i',
#   'got',
#   'suspended',
#   'from',
#   'upwork',
#   '.',
#   'do',
#   'i',
#   'have',
#   'the',
#   'legal',
#   'right',
#   'to',
#   'create',
#   'another',
#   'account',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'process',
#   'to',
#   'becoming',
#   'a',
#   'lawyer',
#   'in',
#   'the',
#   'u',
#   '.',
#   's',
#   '.?'],
#  ['how',
#   'do',
#   'we',
#   'challenge',
#   'our',
#   'freeholder',
#   'if',
#   'we',
#   'suspect',
#   'they',
#   'are',
#   'overcharging',
#   'us',
#   'for',
#   'building',
#   'work',
#   '?'],
#  ['muslim',
#   'women',
#   ':',
#   'what',
#   'emotions',
#   'does',
#   'an',
#   'unmarried',
#   'muslima',
#   ',',
#   'from',
#   'an',
#   'orthodox',
#   'family',
#   ',',
#   'experience',
#   'while',
#   'being',
#   'undressed',
#   'for',
#   'her',
#   'first',
#   'sexual',
#   'intercourse',
#   '?'],
#  ['would',
#   "'",
#   'ramzor',
#   "'",
#   'in',
#   'the',
#   'original',
#   'hebrew',
#   'but',
#   'with',
#   'english',
#   '(',
#   'or',
#   'other',
#   ')',
#   'subtitles',
#   'work',
#   'on',
#   'cable',
#   'or',
#   'broadcast',
#   'tv',
#   '?',
#   'has',
#   'anyone',
#   'tried',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'activities',
#   'to',
#   'do',
#   'with',
#   'children',
#   'when',
#   'visiting',
#   'silchar',
#   ',',
#   'assam',
#   ',',
#   'india',
#   '?'],
#  ['my',
#   'linkedin',
#   'account',
#   'has',
#   'been',
#   'restricted',
#   '.',
#   'how',
#   'can',
#   'i',
#   'get',
#   'them',
#   'to',
#   'unrestrict',
#   '(',
#   'release',
#   ')',
#   'my',
#   'linkedin',
#   'account',
#   '?'],
#  ['what', 'does', '押一付三', '，', '先付后用', 'mean', 'in', 'english', '?'],
#  ['what', 'is', 'the', 'origin', 'of', 'the', 'term', '"', 'hoosier', '"?'],
#  ['how',
#   'the',
#   'internal',
#   'working',
#   'of',
#   'statement',
#   '-',
#   'based',
#   '-',
#   'replication',
#   'happens',
#   'on',
#   'secondary',
#   'node',
#   'of',
#   'mongodb',
#   '?'],
#  ['what',
#   'consumer',
#   'electronics',
#   'segments',
#   'are',
#   'growing',
#   'the',
#   'fastest',
#   '?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'the',
#   'white',
#   'part',
#   'of',
#   'my',
#   'eye',
#   'is',
#   'swollen',
#   '?'],
#  ['what',
#   'are',
#   'we',
#   'sensing',
#   'when',
#   'we',
#   '"',
#   'feel',
#   '"',
#   'someone',
#   "'",
#   's',
#   'presence',
#   '?'],
#  ['how', 'is', 'a', 'compiler', 'program', 'compiled', '?'],
#  ['trump',
#   'supporters',
#   'cite',
#   'a',
#   'shakeup',
#   'of',
#   'd',
#   '.',
#   'c',
#   '.',
#   'as',
#   'a',
#   'primary',
#   'driver',
#   'to',
#   'success',
#   '-',
#   'change',
#   'the',
#   'outcome',
#   'expected',
#   '-',
#   'so',
#   'why',
#   'did',
#   '435',
#   'party',
#   'wag',
#   'house',
#   'members',
#   'get',
#   'in',
#   '?'],
#  ['does',
#   'a',
#   'long',
#   'sleeve',
#   'shirt',
#   'look',
#   'good',
#   'under',
#   'a',
#   'polo',
#   'shirt',
#   '?'],
#  ['it',
#   "'",
#   's',
#   '2016',
#   '.',
#   'dad',
#   'says',
#   'that',
#   'he',
#   'and',
#   'ma',
#   'will',
#   'leave',
#   'the',
#   'country',
#   'if',
#   'hillary',
#   'is',
#   'elected',
#   '.',
#   'they',
#   'are',
#   'big',
#   'republicans',
#   '.',
#   'what',
#   'conservative',
#   'country',
#   'should',
#   'they',
#   'move',
#   'to',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'mind',
#   '-',
#   'blowing',
#   'facts',
#   'about',
#   'netherlands',
#   '?'],
#  ['how', 'do', 'i', 'prepare', 'for', 'a', 'travel', 'quiz', '?'],
#  ['what', 'is', 'all', 'about', 'scholarships', 'for', 'engineering', '?'],
#  ['what',
#   'universities',
#   'does',
#   'petmeds',
#   'recruit',
#   'new',
#   'grads',
#   'from',
#   '?',
#   'what',
#   'majors',
#   'are',
#   'they',
#   'looking',
#   'for',
#   '?'],
#  ['what',
#   'did',
#   'chinese',
#   'soldiers',
#   '(',
#   'in',
#   'general',
#   ')',
#   'think',
#   'of',
#   'americans',
#   'soldiers',
#   'in',
#   'the',
#   'korean',
#   'war',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'get',
#   'the',
#   'best',
#   'employment',
#   'attorney',
#   'in',
#   'los',
#   'angeles',
#   '?'],
#  ['what', "'", 's', 'the', 'most', 'sophisticated', 'indian', 'city', '?'],
#  ['what',
#   'percentage',
#   'of',
#   'quora',
#   'questions',
#   'do',
#   'you',
#   'think',
#   'could',
#   'be',
#   'answered',
#   'with',
#   'a',
#   'simple',
#   'google',
#   'search',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'cook',
#   'a',
#   'steak',
#   'like',
#   'a',
#   'restaurant',
#   'does',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'indoor',
#   'badminton',
#   'courts',
#   'to',
#   'play',
#   '?'],
#  ['is', 'it', 'safe', 'to', 'travel', 'to', 'turkey', 'in', '2016', '?'],
#  ['what',
#   "'",
#   's',
#   'brendan',
#   'fraser',
#   "'",
#   's',
#   'political',
#   'beliefs',
#   '?'],
#  ['when', 'is', 'ekstop', '.', 'com', 'launching', 'in', 'pune', '?'],
#  ['why', 'don', "'", 't', 'most', 'american', 'eat', 'chicken', 'livers', '?'],
#  ['how',
#   'do',
#   'you',
#   'eat',
#   'good',
#   'tasting',
#   'food',
#   'while',
#   'eating',
#   'healthy',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'benefits',
#   'and',
#   'tradeoffs',
#   'of',
#   'pair',
#   'programming',
#   '?'],
#  ['how', 'good', 'are', 'larry', '&', 'sergey', 'at', 'programming', '?'],
#  ['do', 'younger', 'women', 'really', 'like', 'older', 'men', '?'],
#  ['i',
#   'want',
#   'to',
#   'hire',
#   'a',
#   'hacker',
#   'to',
#   'hack',
#   'the',
#   'balance',
#   'of',
#   'an',
#   'emv',
#   'stored',
#   'value',
#   'card',
#   ',',
#   'where',
#   'should',
#   'i',
#   'go',
#   '?'],
#  ['my',
#   'facebook',
#   'is',
#   'hacked',
#   'by',
#   'someone',
#   '.',
#   'how',
#   'can',
#   'i',
#   'get',
#   'back',
#   'the',
#   'old',
#   'facebook',
#   'account',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'get',
#   'quality',
#   'services',
#   'in',
#   'australia',
#   'for',
#   'full',
#   'color',
#   'printed',
#   'pvc',
#   'sticker',
#   '?'],
#  ['is', 'gwern', 'a', 'buddha', '?'],
#  ['why',
#   'was',
#   'jaqen',
#   'h',
#   "'",
#   'ghar',
#   'captured',
#   'in',
#   'the',
#   'first',
#   'place',
#   'with',
#   'the',
#   'other',
#   'two',
#   'prisoners',
#   'if',
#   'he',
#   'has',
#   'such',
#   'skills',
#   '?'],
#  ['what',
#   'is',
#   'your',
#   'review',
#   'of',
#   'university',
#   'of',
#   'north',
#   'carolina',
#   'at',
#   'charlotte',
#   '?'],
#  ['how',
#   'should',
#   'i',
#   'start',
#   'learning',
#   'python',
#   'for',
#   'data',
#   'science',
#   '?'],
#  ['why', 'is', 'adoption', 'so', 'expensive', '?'],
#  ['who', 'is', 'redditceo', 'on', 'reddit', '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'send',
#   'money',
#   'from',
#   'australia',
#   'to',
#   'the',
#   'philippines',
#   '?'],
#  ['what',
#   'are',
#   'computer',
#   'ethics',
#   'and',
#   'what',
#   'are',
#   'some',
#   'examples',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'advantage',
#   'of',
#   'brands',
#   'for',
#   'using',
#   'media',
#   'buyers',
#   'to',
#   'purchase',
#   'advertising',
#   'space',
#   'for',
#   'them',
#   '?'],
#  ['can', 'i', 'take', 'two', 'tylenol', 'and', 'advil', 'together', '?'],
#  ['what',
#   'would',
#   'happen',
#   'if',
#   'a',
#   'very',
#   'large',
#   'number',
#   'of',
#   'people',
#   'went',
#   'to',
#   'the',
#   'bank',
#   'to',
#   'take',
#   'back',
#   'their',
#   'deposits',
#   'simultaneously',
#   '?'],
#  ['what', 'are', 'basics', 'needed', 'for', '"', 'angular', 'js', '"?'],
#  ['what',
#   'is',
#   'exactly',
#   'the',
#   'concept',
#   'of',
#   'trade',
#   '-',
#   'off',
#   'in',
#   'evolutionary',
#   'biology',
#   '?'],
#  ['how', 'do', 'we', 'develop', 'tamil', 'nadu', '?'],
#  ['why',
#   'does',
#   'the',
#   'brain',
#   'not',
#   'start',
#   'recording',
#   'memory',
#   'for',
#   'the',
#   'first',
#   'few',
#   'years',
#   'of',
#   'life',
#   '?'],
#  ['how',
#   'can',
#   'government',
#   'get',
#   'an',
#   'economy',
#   'out',
#   'of',
#   'a',
#   'recession',
#   'with',
#   'fiscal',
#   'policy',
#   '?'],
#  ['can',
#   'you',
#   'put',
#   'some',
#   'tutorials',
#   'for',
#   'learning',
#   'adobe',
#   'illustrator',
#   '?'],
#  ['which',
#   'compiler',
#   'i',
#   'can',
#   'use',
#   'in',
#   'windows',
#   '8',
#   '.',
#   '1',
#   'for',
#   'c',
#   'language',
#   '?'],
#  ['who',
#   'is',
#   'the',
#   'biggest',
#   'traitor',
#   'in',
#   'the',
#   'history',
#   'of',
#   'portugal',
#   '?'],
#  ['what', 'are', 'some', 'good', 'quotation', 'on', 'faith', '?'],
#  ['is',
#   'it',
#   'very',
#   'useful',
#   'for',
#   'students',
#   'go',
#   'abroad',
#   'for',
#   'study',
#   '?'],
#  ['how', 'are', 'the', 'job', 'opportunities', 'in', 'usa', '?'],
#  ['what',
#   'should',
#   'your',
#   'annual',
#   'income',
#   'be',
#   'to',
#   'fly',
#   'first',
#   'class',
#   '?'],
#  ['how', 'do', 'you', 'make', 'a', 'flip', 'flop', 'at', 'home', '?'],
#  ['my',
#   'stepdad',
#   'let',
#   'me',
#   'have',
#   'facebook',
#   ',',
#   'but',
#   'my',
#   'mother',
#   'wouldn',
#   "'",
#   't',
#   'approve',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'aspects',
#   'of',
#   'living',
#   'in',
#   'batna',
#   ',',
#   'algeria',
#   'as',
#   'a',
#   'young',
#   'adult',
#   '?'],
#  ['how',
#   'many',
#   'times',
#   'do',
#   'artists',
#   'act',
#   'out',
#   'or',
#   'get',
#   'someone',
#   'to',
#   'act',
#   'out',
#   'a',
#   'particular',
#   'pose',
#   'that',
#   'they',
#   'wish',
#   'to',
#   'draw',
#   '?'],
#  ['what',
#   'should',
#   'you',
#   'do',
#   'if',
#   'you',
#   'have',
#   'a',
#   'personality',
#   'disorder',
#   'and',
#   'you',
#   'are',
#   'tired',
#   'of',
#   'hurting',
#   'other',
#   'people',
#   '?'],
#  ['can', 'rbi', 'print', 'unlimited', 'currency', '?'],
#  ['should', 'air', 'india', 'be', 'privatised', '?'],
#  ['what', 'human', 'food', 'is', 'very', 'healthy', 'for', 'dogs', '?'],
#  ['why', 'do', 'atms', 'eat', 'cards', '?'],
#  ['is', 'asianet', 'owned', 'by', 'news', 'corp', '?'],
#  ['what',
#   'is',
#   'it',
#   'like',
#   'to',
#   'testdrive',
#   'a',
#   'self',
#   '-',
#   'driving',
#   'car',
#   '?'],
#  ['why', 'do', 'human', 'beings', 'sleep', 'at', 'night', '?'],
#  ['what',
#   'are',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'raising',
#   'kids',
#   'in',
#   'england',
#   'for',
#   'indian',
#   'parents',
#   '?'],
#  ['i',
#   'am',
#   'a',
#   'iit',
#   'jee',
#   'repeater',
#   'and',
#   'i',
#   'dont',
#   'get',
#   'time',
#   'for',
#   'revision',
#   'of',
#   'previous',
#   'chapters',
#   'taught',
#   'in',
#   'coaching',
#   'because',
#   'of',
#   'lot',
#   'of',
#   'homework',
#   '.',
#   'what',
#   'should',
#   'i',
#   'do',
#   '?'],
#  ['three',
#   'balls',
#   'are',
#   'drawn',
#   'from',
#   'a',
#   'bag',
#   'containing',
#   '5',
#   'white',
#   ',',
#   '4',
#   'black',
#   'and',
#   '6',
#   'red',
#   'balls',
#   '.',
#   'find',
#   'the',
#   'probability',
#   'that',
#   'all',
#   'the',
#   'balls',
#   'are',
#   'of',
#   'one',
#   'colors',
#   '?'],
#  ['should',
#   'a',
#   'teacher',
#   'who',
#   'is',
#   'gay',
#   ',',
#   'bi',
#   'or',
#   'trans',
#   'be',
#   'forced',
#   'to',
#   'inform',
#   'his',
#   'or',
#   'her',
#   'class',
#   'of',
#   'this',
#   'by',
#   'the',
#   'school',
#   '?'],
#  ['in',
#   'what',
#   'programming',
#   'language',
#   'are',
#   'chrome',
#   'extensions',
#   'written',
#   '?',
#   'what',
#   'do',
#   'i',
#   'need',
#   'to',
#   'know',
#   'to',
#   'start',
#   'coding',
#   'them',
#   '?'],
#  ['is', 'there', 'a', 'tibetan', 'market', 'in', 'bangalore', '?'],
#  ['does',
#   'blocking',
#   'somebody',
#   'on',
#   'snapchat',
#   'clear',
#   'saved',
#   'messages',
#   '?'],
#  ['i',
#   'am',
#   'in',
#   '10th',
#   '.',
#   'how',
#   'can',
#   'i',
#   'get',
#   'admission',
#   'in',
#   'the',
#   'indian',
#   'institute',
#   'of',
#   'science',
#   '?'],
#  ['why', 'would', 'you', 'buy', 'an', 'iphone', '7', '?'],
#  ['what',
#   'type',
#   'of',
#   'government',
#   'does',
#   'turkey',
#   'have',
#   '?',
#   'how',
#   'does',
#   'it',
#   'compare',
#   'to',
#   'the',
#   'one',
#   'in',
#   'brazil',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'job',
#   'interview',
#   'questions',
#   'you',
#   "'",
#   've',
#   'ever',
#   'asked',
#   'or',
#   'been',
#   'asked',
#   '?'],
#  ['how', 'many', 'points', 'are', 'in', 'a', 'gram', 'of', 'meth', '?'],
#  ['which', 'k', '-', 'pop', 'idols', 'are', 'not', 'koreans', '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'dress',
#   'code',
#   'for',
#   'a',
#   'software',
#   'engineer',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'security',
#   'concerns',
#   'about',
#   'yammer',
#   '?'],
#  ['donald',
#   'trump',
#   ':',
#   'why',
#   'wouldn',
#   "'",
#   't',
#   'you',
#   'vote',
#   'for',
#   'donald',
#   'trump',
#   'for',
#   'president',
#   '?'],
#  ['i',
#   'am',
#   '25',
#   'working',
#   'in',
#   'digital',
#   'marketing',
#   '9',
#   'hours',
#   'a',
#   'day',
#   '.',
#   'i',
#   'want',
#   'to',
#   'spend',
#   'another',
#   '5',
#   'to',
#   '8',
#   'hours',
#   'for',
#   'myself',
#   'at',
#   'home',
#   ',',
#   'to',
#   'work',
#   'on',
#   'my',
#   'startup',
#   '.',
#   'it',
#   'is',
#   'healthy',
#   'to',
#   'spend',
#   '15',
#   'to',
#   '18',
#   'hours',
#   'daily',
#   'for',
#   'work',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'craziest',
#   '/',
#   'weirdest',
#   'things',
#   'you',
#   "'",
#   've',
#   'seen',
#   'a',
#   'lion',
#   'do',
#   '?'],
#  ['what', 'has', 'gone', 'wrong', 'at', 'chelsea', 'fc', '?'],
#  ['how',
#   'do',
#   'i',
#   'control',
#   'someone',
#   'who',
#   'is',
#   'very',
#   'dominating',
#   '?'],
#  ['what',
#   'is',
#   'an',
#   'easy',
#   'way',
#   'to',
#   'clean',
#   'toothpaste',
#   'stains',
#   'from',
#   'a',
#   'shirt',
#   'without',
#   'washing',
#   'it',
#   '?'],
#  ['job',
#   'interviews',
#   ':',
#   'should',
#   'someone',
#   'with',
#   'asperger',
#   "'",
#   's',
#   'disclose',
#   'their',
#   'asperger',
#   "'",
#   's',
#   'in',
#   'a',
#   'job',
#   'interview',
#   '?'],
#  ['should',
#   'quora',
#   'allow',
#   'the',
#   'option',
#   'to',
#   'bookmark',
#   'questions',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'easiest',
#   'and',
#   'safest',
#   'way',
#   'to',
#   'make',
#   'meth',
#   '?'],
#  ['which', 'is', 'the', 'best', 'book', 'for', 'control', 'system', '?'],
#  ['what',
#   'do',
#   'you',
#   'call',
#   'someone',
#   'who',
#   'is',
#   'attracted',
#   'to',
#   'women',
#   'but',
#   'doesn',
#   "'",
#   't',
#   'want',
#   'to',
#   'have',
#   'sex',
#   'with',
#   'them',
#   'or',
#   'be',
#   'in',
#   'a',
#   'relationship',
#   'with',
#   'them',
#   '?'],
#  ...]

# %%
assert all(isinstance(row, (list, tuple)) for row in data_tok), "please convert each line into a list of tokens (strings)"
assert all(all(isinstance(tok, str) for tok in row) for row in data_tok), "please convert each line into a list of tokens (strings)"
is_latin = lambda tok: all('a' <= x.lower() <= 'z' for x in tok)
assert all(map(lambda l: not is_latin(l) or l.islower(), map(' '.join, data_tok))), "please make sure to lowercase the data"

# %%
print([' '.join(row) for row in data_tok[:2]])
# Out:
# ["can i get back with my ex even though she is pregnant with another guy ' s baby ?", 'what are some ways to overcome a fast food addiction ?']

# %% [markdown]
# __Word vectors:__ as the saying goes, there's more than one way to train word embeddings. There's Word2Vec and GloVe with different objective functions. Then there's fasttext that uses character-level models to train word embeddings.
#
# The choice is huge, so let's start someplace small: __gensim__ is another nlp library that features many vector-based models incuding word2vec.

# %%
from gensim.models import Word2Vec
model = Word2Vec(data_tok, 
                 size=32,      # embedding vector size
                 min_count=5,  # consider words that occured at least 5 times
                 window=5).wv  # define context as a 5-word window around the target word
# Out:
# c:\users\wzm\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# now you can get word vectors !
model.get_vector('anything')
# Out:
# array([ 1.9231837 , -0.7087102 , -2.059314  , -1.4083858 ,  0.18482068,
#        -1.2317226 ,  2.1878147 , -0.43599033, -2.341395  ,  0.11181548,
#        -1.8366613 ,  0.15372004,  2.776266  , -0.45586964,  1.9696611 ,
#         2.8510013 , -0.8676105 , -4.869431  ,  2.557877  ,  1.9735059 ,
#         2.764995  , -0.19742037, -1.0261557 , -0.43159595, -0.0994176 ,
#        -0.7011709 , -0.8300928 , -5.6150413 ,  0.24620187, -1.6516075 ,
#         2.9440422 ,  0.8949008 ], dtype=float32)

# %%
# or query similar words directly. Go play with it!
model.most_similar('bread')
# Out:
# c:\users\wzm\appdata\local\programs\python\python36\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('rice', 0.9475276470184326),
#  ('cheese', 0.9337195158004761),
#  ('sauce', 0.9265300631523132),
#  ('butter', 0.9230688214302063),
#  ('beans', 0.9186348915100098),
#  ('fruit', 0.9149258136749268),
#  ('corn', 0.9100850820541382),
#  ('banana', 0.9057000875473022),
#  ('potatoes', 0.9010831117630005),
#  ('potato', 0.899056077003479)]

# %% [markdown]
# ### Using pre-trained model
#
# Took it a while, huh? Now imagine training life-sized (100~300D) word embeddings on gigabytes of text: wikipedia articles or twitter posts.
#
# Thankfully, nowadays you can get a pre-trained word embedding model in 2 lines of code (no sms required, promise).

# %%
import gensim.downloader as api
model = api.load('glove-twitter-100')
# Out:
# [==================================================] 100.0% 387.1/387.1MB downloaded

# %%
model.most_similar(positive=["coder", "money"], negative=["brain"])
# Out:
# [('broker', 0.5820155739784241),
#  ('bonuses', 0.5424473285675049),
#  ('banker', 0.538511335849762),
#  ('designer', 0.5197198390960693),
#  ('merchandising', 0.4964233934879303),
#  ('treet', 0.49220192432403564),
#  ('shopper', 0.4920561909675598),
#  ('part-time', 0.49128279089927673),
#  ('freelance', 0.4843311905860901),
#  ('aupair', 0.4796452522277832)]

# %% [markdown]
# ### Visualizing word vectors
#
# One way to see if our vectors are any good is to plot them. Thing is, those vectors are in 30D+ space and we humans are more used to 2-3D.
#
# Luckily, we machine learners know about __dimensionality reduction__ methods.
#
# Let's use that to plot 1000 most frequent words

# %%
words = sorted(model.vocab.keys(), 
               key=lambda word: model.vocab[word].count,
               reverse=True)[:1000]

print(words[::100])
# Out:
# ['<user>', '_', 'please', 'apa', 'justin', 'text', 'hari', 'playing', 'once', 'sei']

# %%
# model.vocab.keys()

# %%
# for each word, compute it's vector with model
word_vectors = []

for i in words:
    word_vectors.append(model.get_vector(i))

# %%
word_vectors = np.array(word_vectors)

# %%
assert isinstance(word_vectors, np.ndarray)
assert word_vectors.shape == (len(words), 100)
assert np.isfinite(word_vectors).all()

# %% [markdown]
# #### Linear projection: PCA
#
# The simplest linear dimensionality reduction method is __P__rincipial __C__omponent __A__nalysis.
#
# In geometric terms, PCA tries to find axes along which most of the variance occurs. The "natural" axes, if you wish.
#
# <img src="https://github.com/yandexdataschool/Practical_RL/raw/master/yet_another_week/_resource/pca_fish.png" style="width:30%">
#
#
# Under the hood, it attempts to decompose object-feature matrix $X$ into two smaller matrices: $W$ and $\hat W$ minimizing _mean squared error_:
#
# $$\|(X W) \hat{W} - X\|^2_2 \to_{W, \hat{W}} \min$$
# - $X \in \mathbb{R}^{n \times m}$ - object matrix (**centered**);
# - $W \in \mathbb{R}^{m \times d}$ - matrix of direct transformation;
# - $\hat{W} \in \mathbb{R}^{d \times m}$ - matrix of reverse transformation;
# - $n$ samples, $m$ original dimensions and $d$ target dimensions;

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

pca = PCA(n_components=2, random_state=2018)
scaler = StandardScaler()
# map word vectors onto 2d plane with PCA. Use good old sklearn api (fit, transform)
# after that, normalize vectors to make sure they have zero mean and unit variance
word_vectors_pca = pca.fit_transform(word_vectors)
word_vectors_pca = scaler.fit_transform(word_vectors_pca)

# and maybe MORE OF YOUR CODE here :)

# %%
assert word_vectors_pca.shape == (len(word_vectors), 2), "there must be a 2d vector for each word"
assert max(abs(word_vectors_pca.mean(0))) < 1e-5, "points must be zero-centered"
assert max(abs(1.0 - word_vectors_pca.std(0))) < 1e-2, "points must have unit variance"

# %% [markdown]
# #### Let's draw it!

# %%
import bokeh.models as bm, bokeh.plotting as pl
from bokeh.io import output_notebook
output_notebook()

def draw_vectors(x, y, radius=10, alpha=0.25, color='blue',
                 width=600, height=400, show=True, **kwargs):
    """ draws an interactive plot for data points with auxilirary info on hover """
    if isinstance(color, str): color = [color] * len(x)
    data_source = bm.ColumnDataSource({ 'x' : x, 'y' : y, 'color': color, **kwargs })

    fig = pl.figure(active_scroll='wheel_zoom', width=width, height=height)
    fig.scatter('x', 'y', size=radius, color='color', alpha=alpha, source=data_source)

    fig.add_tools(bm.HoverTool(tooltips=[(key, "@" + key) for key in kwargs.keys()]))
    if show: pl.show(fig)
    return fig
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
draw_vectors(word_vectors_pca[:, 0], word_vectors_pca[:, 1], token=words)

# hover a mouse over there and see if you can identify the clusters
# Out:
#   <div class="bk-root" id="d37be368-179c-407d-ae8f-f6712da911eb"></div>
# Figure(id='1003', ...)

# %% [markdown]
# ### Visualizing neighbors with t-SNE
# PCA is nice but it's strictly linear and thus only able to capture coarse high-level structure of the data.
#
# If we instead want to focus on keeping neighboring points near, we could use TSNE, which is itself an embedding method. Here you can read __[more on TSNE](https://distill.pub/2016/misread-tsne/)__.

# %%
from sklearn.manifold import TSNE

# map word vectors onto 2d plane with TSNE. hint: use verbose=100 to see what it's doing.
# normalize them as just lke with pca


word_tsne = X_embedded = TSNE(n_components=2).fit_transform(word_vectors)
word_tsne = scaler.fit_transform(word_tsne)

# %%
draw_vectors(word_tsne[:, 0], word_tsne[:, 1], color='green', token=words)
# Out:
#   <div class="bk-root" id="f26e3b0d-cebb-4fa4-be5a-f6ddd0d5fb99"></div>
# Figure(id='1112', ...)

# %% [markdown]
# ### Visualizing phrases
#
# Word embeddings can also be used to represent short phrases. The simplest way is to take __an average__ of vectors for all tokens in the phrase with some weights.
#
# This trick is useful to identify what data are you working with: find if there are any outliers, clusters or other artefacts.
#
# Let's try this new hammer on our data!

# %%
def get_phrase_embedding(phrase):
    """
    Convert phrase to a vector by aggregating it's word embeddings. See description above.
    """
    # 1. lowercase phrase
    # 2. tokenize phrase
    # 3. average word vectors for all words in tokenized phrase
    # skip words that are not in model's vocabulary
    # if all words are missing from vocabulary, return zeros
    
    vector = np.zeros([model.vector_size], dtype='float32')
    
    phrase = phrase.lower()
    phrase = tokenizer.tokenize(phrase)
    
    phrase_vectors = []
    
    for i in phrase:
        if i in model.vocab.keys():
            phrase_vectors.append(model.get_vector(i))
    
    phrase_vectors = np.array(phrase_vectors)
    
    if len(phrase_vectors) == 0:
        return vector
    
    phrase_vectors = np.mean(phrase_vectors, axis=0)
    
    return phrase_vectors

# %%
vector = get_phrase_embedding("I'm very sure. This never happened to me before...")

assert np.allclose(vector[::10],
                   np.array([ 0.31807372, -0.02558171,  0.0933293 , -0.1002182 , -1.0278689 ,
                             -0.16621883,  0.05083408,  0.17989802,  1.3701859 ,  0.08655966],
                              dtype=np.float32))

# %%
# let's only consider ~5k phrases for a first run.
chosen_phrases = data[::len(data) // 1000]

# compute vectors for chosen phrases

phrase_vectors = []

for i in chosen_phrases:
    phrase_vectors.append(get_phrase_embedding(i))

phrase_vectors = np.array(phrase_vectors)

# %%
assert isinstance(phrase_vectors, np.ndarray) and np.isfinite(phrase_vectors).all()
assert phrase_vectors.shape == (len(chosen_phrases), model.vector_size)

# %%
# map vectors into 2d space with pca, tsne or your other method of choice
# don't forget to normalize

phrase_vectors_2d = TSNE(verbose=1000).fit_transform(phrase_vectors)

phrase_vectors_2d = (phrase_vectors_2d - phrase_vectors_2d.mean(axis=0)) / phrase_vectors_2d.std(axis=0)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1001 samples in 0.003s...
# [t-SNE] Computed neighbors for 1001 samples in 0.152s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1001
# [t-SNE] Computed conditional probabilities for sample 1001 / 1001
# [t-SNE] Mean sigma: 0.477874
# [t-SNE] Computed conditional probabilities in 0.021s
# [t-SNE] Iteration 50: error = 78.5456390, gradient norm = 0.3256128 (50 iterations in 9.445s)
# [t-SNE] Iteration 100: error = 78.8198395, gradient norm = 0.3190000 (50 iterations in 10.487s)
# [t-SNE] Iteration 150: error = 79.2563477, gradient norm = 0.3189905 (50 iterations in 10.680s)
# [t-SNE] Iteration 200: error = 78.4569016, gradient norm = 0.3237619 (50 iterations in 10.761s)
# [t-SNE] Iteration 250: error = 77.5534439, gradient norm = 0.3449683 (50 iterations in 10.738s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.553444
# [t-SNE] Iteration 300: error = 2.0323992, gradient norm = 0.0024755 (50 iterations in 7.535s)
# [t-SNE] Iteration 350: error = 1.9257922, gradient norm = 0.0008945 (50 iterations in 5.949s)
# [t-SNE] Iteration 400: error = 1.8925741, gradient norm = 0.0005614 (50 iterations in 5.774s)
# [t-SNE] Iteration 450: error = 1.8706324, gradient norm = 0.0005701 (50 iterations in 5.709s)
# [t-SNE] Iteration 500: error = 1.8618598, gradient norm = 0.0002093 (50 iterations in 5.583s)
# [t-SNE] Iteration 550: error = 1.8555769, gradient norm = 0.0001628 (50 iterations in 5.603s)
# [t-SNE] Iteration 600: error = 1.8505425, gradient norm = 0.0001468 (50 iterations in 5.611s)
# [t-SNE] Iteration 650: error = 1.8470184, gradient norm = 0.0001082 (50 iterations in 5.578s)
# [t-SNE] Iteration 700: error = 1.8449545, gradient norm = 0.0000861 (50 iterations in 5.619s)
# [t-SNE] Iteration 750: error = 1.8431641, gradient norm = 0.0001132 (50 iterations in 5.584s)
# [t-SNE] Iteration 800: error = 1.8419528, gradient norm = 0.0001392 (50 iterations in 5.554s)
# [t-SNE] Iteration 850: error = 1.8396780, gradient norm = 0.0000959 (50 iterations in 5.609s)
# [t-SNE] Iteration 900: error = 1.8374462, gradient norm = 0.0001669 (50 iterations in 5.510s)
# [t-SNE] Iteration 950: error = 1.8354813, gradient norm = 0.0001015 (50 iterations in 5.531s)
# [t-SNE] Iteration 1000: error = 1.8346722, gradient norm = 0.0000844 (50 iterations in 5.625s)
# [t-SNE] KL divergence after 1000 iterations: 1.834672

# %%
draw_vectors(phrase_vectors_2d[:, 0], phrase_vectors_2d[:, 1],
             phrase=[phrase[:50] for phrase in chosen_phrases],
             radius=20,)
# Out:
#   <div class="bk-root" id="5fd63a92-6399-4312-a297-42c51b61e688"></div>
# Figure(id='1230', ...)

# %% [markdown]
# Finally, let's build a simple "similar question" engine with phrase embeddings we've built.

# %%
# compute vector embedding for all lines in data
data_vectors = np.array([get_phrase_embedding(l) for l in data])

# %%
data = np.array(data)

# %%
data.shape
# Out:
# (537272,)

# %%
a = [1,2,4]
a.reverse()
a
# Out:
# [4, 2, 1]

# %%
# 没有处理分母为0的情况

def my_cos(v1, v2):
    a = np.sqrt(np.sum(np.power(v1, 2))) * np.sqrt(np.sum(np.power(v2, 2)))
    if a == 0:
        return 0
    else:
        return ((v1.dot(v2)) / a)

# 可以先使用np.argartition进行排序，然后再使用npargsort准确的排序
def find_nearest(query, k=10):
    """
    given text line (query), return k most similar lines from data, sorted from most to least similar
    similarity should be measured as cosine between query and line embedding vectors
    hint: it's okay to use global variables: data and data_vectors. see also: np.argpartition, np.argsort
    """
    query = get_phrase_embedding(query)
    
    data_vectors_cos = [my_cos(i, query) for i in data_vectors]
    data_vectors_cos = list(np.argsort(data_vectors_cos))
    data_vectors_cos.reverse()

    return data[data_vectors_cos][:k]

# %%
results = find_nearest(query="How do i enter the matrix?", k=10)

# print(results)
print(''.join(results))

assert len(results) == 10 and isinstance(results[0], str)
assert results[0] == 'How do I get to the dark web?\n'
assert results[3] == 'What can I do to save the world?\n'
# Out:
# How do I get to the dark web?
# What should I do to enter hollywood?
# How do I use the Greenify app?
# What can I do to save the world?
# How do I win this?
# How do I think out of the box? How do I learn to think out of the box?
# How do I find the 5th dimension?
# How do I use the pad in MMA?
# How do I estimate the competition?
# What do I do to enter the line of event management?

# %%
find_nearest(query="How does Trump?", k=10)
# Out:
# array(['What does Donald Trump think about Israel?\n',
#        'What books does Donald Trump like?\n',
#        'What does Donald Trump think of India?\n',
#        'What does India think of Donald Trump?\n',
#        'What does Donald Trump think of China?\n',
#        'What does Donald Trump think about Pakistan?\n',
#        'What companies does Donald Trump own?\n',
#        'What does Dushka Zapata think about Donald Trump?\n',
#        'How does it feel to date Ivanka Trump?\n',
#        'What does salesforce mean?\n'], dtype='<U1170')

# %%
find_nearest(query="Why don't i ask a question myself?", k=10)
# Out:
# array(["Why don't I get a date?\n",
#        "Why do you always answer a question with a question? I don't, or do I?\n",
#        "Why can't I ask a question anonymously?\n",
#        "Why don't I get a girlfriend?\n",
#        "Why don't I have a boyfriend?\n", "I don't have no question?\n",
#        "Why can't I take a joke?\n", "Why don't I ever get a girl?\n",
#        "Can I ask a girl out that I don't know?\n",
#        "Why don't I have a girlfriend?\n"], dtype='<U1170')

# %% [markdown]
# __Now what?__
# * Try running TSNE on all data, not just 1000 phrases
# * See what other embeddings are there in the model zoo: `gensim.downloader.info()`
# * Take a look at [FastText](https://github.com/facebookresearch/fastText) embeddings
# * Optimize find_nearest with locality-sensitive hashing: use [nearpy](https://github.com/pixelogik/NearPy) or `sklearn.neighbors`.
